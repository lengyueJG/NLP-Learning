# %% [markdown]
# # 读取数据

# %%
import pandas as pd

df=pd.read_csv('./data/military.tsv', sep='\t')
df.head()
# Out:
#                                                 text label
# 0  南亚地区的权威军事来源称，巴基斯坦陆军进口了中国生产的ＣＨ－３Ａ型攻击无人机。但是截至２０１...    武器
# 1  ［提要］　在遂行非战争军事行动任务中，强化一切行动坚决听从党中央、中央军委指挥。非战争军事行...    军事
# 2  原题：美智库教台军对付大陆两栖登陆战环球时报特约记者：在美国“重返亚太”的军事格局下，冷战...    武器
# 3  东方网消息：５月３０日，俄罗斯《军工信使》周刊报道称，据非正式消息透露，目前中国已经从瑞典成...    武器
# 4  《澳大利亚人报》网站６月２日报道　题：澳中秘密“战”　曝光陆克文政府　２００９年国防白皮书...    军事

# %%
df['text'][0]
# Out:
# '南亚地区的权威军事来源称，巴基斯坦陆军进口了中国生产的ＣＨ－３Ａ型攻击无人机。但是截至２０１２年，只进口了飞机本身，没有进口ＡＲ—１反坦克导弹。\ue40c巴基斯坦陆军消息来源对加拿大《汉和防务评论》称，目前正在对ＣＨ—３进行测试，一旦效果理想，就会考虑进口ＡＲ—１反坦克导弹。\ue40c报道称，巴基斯坦非常重视ＣＨ—３，目前还在考虑是否由巴基斯坦自己生产的可能性，相关的构思已经进行了较长时间。\ue40cＣＨ—３的最大航程２４００公里，滞空时间１２小时。中国陆军也在对ＣＨ—３进行测试。ＡＲ—１反坦克导弹重４５公斤，射程８公里，惯性加ＧＰＳ诱导，１．１马赫射速。\ue40c其他权威消息来源还透露了更多的阿联酋进口“翼龙”攻击无人机的状况，这种无人机在后来的多次打靶过程中不太顺利，原因不明。中东地区的酷热天气可能影响了无人机与地面传感器之间的通信畅通。\ue40c报道称，“翼龙”是成都飞机设计所（中航集团）设计，而武器系统是兵器工业集团的产品，也可能是两者在匹配方面出现了问题。“翼龙”的最大载弹量为２００公斤，最大滞空时间２０小时。'

# %% [markdown]
# # 清洗

# %%
#全角转半角
def full_to_half(sentence):      #输入为一个句子
    change_sentence=""
    for word in sentence:
        inside_code=ord(word)
        if inside_code==12288:    #全角空格直接转换
            inside_code=32
        elif inside_code>=65281 and inside_code<=65374:  #全角字符（除空格）根据关系转化
            inside_code-=65248
        change_sentence+=chr(inside_code)
    return change_sentence

# %%
half_texts = list(map(lambda s: full_to_half(s), df['text']))

# %%
import re
# 去掉文本中的\u3000以及、
pattern = '\u3000|\ue40c| '
def process(our_data,pattern=pattern):
    m1 = map(lambda s: re.sub(pattern, '',s), our_data)
    return list(m1)
# content_rm_sign = process(contents_l,pattern)

# %%
processed_texts = process(half_texts)

# %%
processed_texts[0]
# Out:
# '南亚地区的权威军事来源称,巴基斯坦陆军进口了中国生产的CH-3A型攻击无人机。但是截至2012年,只进口了飞机本身,没有进口AR—1反坦克导弹。巴基斯坦陆军消息来源对加拿大《汉和防务评论》称,目前正在对CH—3进行测试,一旦效果理想,就会考虑进口AR—1反坦克导弹。报道称,巴基斯坦非常重视CH—3,目前还在考虑是否由巴基斯坦自己生产的可能性,相关的构思已经进行了较长时间。CH—3的最大航程2400公里,滞空时间12小时。中国陆军也在对CH—3进行测试。AR—1反坦克导弹重45公斤,射程8公里,惯性加GPS诱导,1.1马赫射速。其他权威消息来源还透露了更多的阿联酋进口“翼龙”攻击无人机的状况,这种无人机在后来的多次打靶过程中不太顺利,原因不明。中东地区的酷热天气可能影响了无人机与地面传感器之间的通信畅通。报道称,“翼龙”是成都飞机设计所(中航集团)设计,而武器系统是兵器工业集团的产品,也可能是两者在匹配方面出现了问题。“翼龙”的最大载弹量为200公斤,最大滞空时间20小时。'

# %% [markdown]
# # 分词

# %%
import jieba
seg_texts=list(map(lambda s: jieba.lcut(s), processed_texts))
# Out:
# Building prefix dict from the default dictionary ...
# Loading model from cache /tmp/jieba.cache
# Loading model cost 0.639 seconds.
# Prefix dict has been built successfully.

# %%
print(seg_texts[0])
# Out:
# ['南亚地区', '的', '权威', '军事', '来源', '称', ',', '巴基斯坦', '陆军', '进口', '了', '中国', '生产', '的', 'CH', '-', '3', 'A型', '攻击', '无人机', '。', '但是', '截至', '2012', '年', ',', '只', '进口', '了', '飞机', '本身', ',', '没有', '进口', 'AR', '—', '1', '反坦克', '导弹', '。', '巴基斯坦', '陆军', '消息来源', '对', '加拿大', '《', '汉', '和', '防务', '评论', '》', '称', ',', '目前', '正在', '对', 'CH', '—', '3', '进行', '测试', ',', '一旦', '效果', '理想', ',', '就', '会', '考虑', '进口', 'AR', '—', '1', '反坦克', '导弹', '。', '报道', '称', ',', '巴基斯坦', '非常重视', 'CH', '—', '3', ',', '目前', '还', '在', '考虑', '是否', '由', '巴基斯坦', '自己', '生产', '的', '可能性', ',', '相关', '的', '构思', '已经', '进行', '了', '较长时间', '。', 'CH', '—', '3', '的', '最大', '航程', '2400', '公里', ',', '滞空', '时间', '12', '小时', '。', '中国', '陆军', '也', '在', '对', 'CH', '—', '3', '进行', '测试', '。', 'AR', '—', '1', '反坦克', '导弹', '重', '45', '公斤', ',', '射程', '8', '公里', ',', '惯性', '加', 'GPS', '诱导', ',', '1.1', '马赫', '射速', '。', '其他', '权威', '消息来源', '还', '透露', '了', '更', '多', '的', '阿联酋', '进口', '“', '翼龙', '”', '攻击', '无人机', '的', '状况', ',', '这种', '无人机', '在', '后来', '的', '多次', '打靶', '过程', '中不太', '顺利', ',', '原因', '不明', '。', '中东地区', '的', '酷热', '天气', '可能', '影响', '了', '无人机', '与', '地面', '传感器', '之间', '的', '通信', '畅通', '。', '报道', '称', ',', '“', '翼龙', '”', '是', '成都', '飞机', '设计所', '(', '中航', '集团', ')', '设计', ',', '而', '武器', '系统', '是', '兵器工业', '集团', '的', '产品', ',', '也', '可能', '是', '两者', '在', '匹配', '方面', '出现', '了', '问题', '。', '“', '翼龙', '”', '的', '最大', '载弹量', '为', '200', '公斤', ',', '最大', '滞空', '时间', '20', '小时', '。']

# %% [markdown]
# ## 词典

# %%
# 歼10等只在一个文本中出现，统计意义不大
dict_name = './data/military_dict.txt'
jieba.load_userdict(dict_name)

# %%
i = 4
print(jieba.lcut(processed_texts[i]))
# Out:
# ['《', '澳大利亚人', '报', '》', '网站', '6', '月', '2', '日', '报道', '题', ':', '澳中', '秘密', '“', '战', '”', '曝光', '陆克文', '政府', '2009', '年', '国防', '白皮书', '的', '一个', '秘密', '章节', '详细', '介绍', '了', '澳大利亚', '与', '中国', '打', '一场', '战争', '的', '计划', '。', '根据', '该', '计划', ',', '澳大利亚', '海军', '潜艇', '将', '帮助', '封锁', '中国', '的', '贸易', '线路', ',', '而', '中国', '可能', '会', '向', '澳大利亚', '目标', '发射', '导弹', '进行', '报复', '。', '据', '新书', '《', '王国', '与', '资源', ':', '中国', '、', '澳大利亚', '、', '恐惧', '与', '贪婪', '》', '透露', ',', '白皮书', '提出', '的', '军力', '2030', '—', '—', '将', '包括', '12', '艘', '装备', '导弹', '的', '大型', '常规', '潜艇', '、', '革命性', '的', '联合', '攻击', '战斗机', '、', '防空', '驱逐舰', '和', '巨型', '登陆舰', '—', '—', '正在', '筹建', '之中', ',', '以', '应对', '可能', '发生', '在', '澳大利亚', '与其', '主要', '贸易', '伙伴', '之间', '的', '战争', '。', '在', '2009', '年', '5', '月', '白皮书', '发表', '前夕', ',', '本报', '曾', '对', '澳大利亚', '各', '安全', '和', '情报机构', '间', '展开', '的', '辩论', '进行', '过', '广泛', '报道', '。', '当时', '它们', '辩论', '的', '话题', '是', ':', '中国', '不断', '增加', '对', '武装力量', '的', '投入', ',', '是否', '会', '构成威胁', '。', '公开', '版', '的', '白皮书', '没有', '宣称', '报告', '作者', '担心', '与', '中国', '爆发', '战争', '。', '为了', '避免', '冒犯', '中国', ',', '并', '让', '官员', '们', '有', '某种程度', '的', '推诿', '余地', ',', '有关', '未来', '可能', '爆发', '冲突', '的', '讨论', '使用', '了', '诸如', '一个', '“', '大国', '对手', '”', '这样', '的', '委婉', '语', '。', '新书', '的', '作者', '、', '本报', '经济', '栏目', '主编', '戴维', '·', '尤伦', '还', '透露', ',', '有关', '方面', '曾', '向', '财政部', '施加', '巨大', '压力', ',', '要求', '其为', '大量', '新型', '装备', '编制', '详细', '预算', ',', '但', '大部分', '相关', '信息', '也', '从', '公开', '版', '白皮书', '中', '消失', '了', '。', '该书', '描述', '了', '澳大利亚国防军', '关键人物', '和', '情报机构', '之间', '的', '激烈', '辩论', '。', '前者', '认为', ',', '澳大利亚', '需要', '作好', '与', '中国', '爆发', '冲突', '的', '准备', ',', '后者', '则', '表示', ',', '中国', '没有', '扩张', '野心', ',', '不大可能', '构成', '这样', '的', '威胁', '。', '公开', '版', '白皮书', '对', '战略', '环境', '和', '需要', '购买', '的', '军事装备', '进行', '了', '概述', '。', '这本', '新书', '说', ':', '“', '但文内', '并', '没有', '包括', '详细', '审视', '预料中', '的', '威胁', '以及', '为', '应对', '这些', '威胁', '澳大利亚', '所', '需', '的', '防务', '力量', '结构', '的', '绝密', '章节', '。', '”', '被删', '章节', '主要', '讲述', '的', '是', '澳大利亚', '和', '美国', '一起', '与', '中国', '打', '一场空', '海战', '的', '能力', '。', '相关', '计划', '涉及', '在', '远离', '中国', '的', '区域', '进行', '封锁', ',', '但', '目的', '是', '控制', '中国', '的', '海上', '航线', ',', '使', '其', '工业生产', '所', '依赖', '的', '自然资源', '的', '输送', '陷入', '停顿', '。', '白皮书', '说', ':', '“', '预计', '一个', '大国', '对手', '会', '对', '这些', '封锁', '作出反应', ',', '进行', '布雷', '和', '袭击', '港口', '。', '“', '国防部', '的', '部分', '想法', '是', ',', '如果', '与', '美国', '爆发', '冲突', ',', '中国', '将', '试图', '摧毁', '艾丽斯', '斯普林斯', '附近', '的', '美', '澳松峡', '信号', '设施', '。', '该', '设施', '对于', '指导', '美国', '在', '亚洲', '的', '军事行动', '至关重要', '......', '白皮书', '设想', '了', '一种', '截然不同', '的', '局势', ',', '在', '这个', '局势', '中', ',', '澳大利亚', '与', '美国', '在', '南中国海', '(', '以该', '地区', '为例', ')', '展开', '的', '联合', '海军', '作战', '行动', '可能', '导致', '中国', '直接', '袭击', '澳大利亚', '......', '“', '中国军力', '能', '达到', '5000', '公里', '以外', '并触', '碰到', '澳大利亚', ',', '这一', '能力', '是', '战略', '环境', '的', '一个', '新', '因素', '。', '”', '这', '就', '意味着', '澳大利亚', '需要', '一支', '能力', '大幅提高', '、', '能够', '进行', '远距离', '作战', '和', '本土', '防御', '的', '军队', '。', '尤伦', '指出', ',', '所有', '这些', '均', '未', '出现', '在', '公开', '版', '白皮书', '中', ',', '但', '公开', '版', '白皮书', '包含', '的', '很多', '信息', '加上', '媒体', '有关', '中国', '威胁', '的', '评论', '足以', '让', '北京', '领会', '其中', '的', '含意', '。', '在', '白皮书', '发表', '之前', ',', '时任', '澳大利亚', '总理', '陆克文派', '白皮书', '的', '主要', '作者', '、', '国防部', '官员', '迈克', '·', '佩苏略', '前往', '北京', ',', '向', '中国', '官员', '介绍', '白皮书', '的', '内容', '。', '佩苏略', '告诉', '中国国防部', '、', '外交部', '和', '军队', '的', '有关', '官员', ',', '澳大利亚', '媒体', '的', '报道', '强调', '了', '白皮书', '对', '中国', '军队', '现代化', '的', '评论', ',', '这些', '报道', '与', '澳', '政府', '无关', '。', '返回', '堪培拉', '后', ',', '佩苏略', '向', '美国使馆', '人员', '简要', '介绍', '了', '北京', '之行', '的', '情况', '。', '他', '告诉', '美国', '人', ',', '通过', '对', '白皮书', '的', '客观', '解读', ',', '中国', '人会', '发现', '这份', '文件', '根本', '没有', '提到', '“', '中国', '威胁', '”', '。', '中国', '媒体', '当时', '表示', ',',  ...

# %%
processed_texts[i]
# Out:
# '《澳大利亚人报》网站6月2日报道题:澳中秘密“战”曝光陆克文政府2009年国防白皮书的一个秘密章节详细介绍了澳大利亚与中国打一场战争的计划。根据该计划,澳大利亚海军潜艇将帮助封锁中国的贸易线路,而中国可能会向澳大利亚目标发射导弹进行报复。据新书《王国与资源:中国、澳大利亚、恐惧与贪婪》透露,白皮书提出的军力2030——将包括12艘装备导弹的大型常规潜艇、革命性的联合攻击战斗机、防空驱逐舰和巨型登陆舰——正在筹建之中,以应对可能发生在澳大利亚与其主要贸易伙伴之间的战争。在2009年5月白皮书发表前夕,本报曾对澳大利亚各安全和情报机构间展开的辩论进行过广泛报道。当时它们辩论的话题是:中国不断增加对武装力量的投入,是否会构成威胁。公开版的白皮书没有宣称报告作者担心与中国爆发战争。为了避免冒犯中国,并让官员们有某种程度的推诿余地,有关未来可能爆发冲突的讨论使用了诸如一个“大国对手”这样的委婉语。新书的作者、本报经济栏目主编戴维·尤伦还透露,有关方面曾向财政部施加巨大压力,要求其为大量新型装备编制详细预算,但大部分相关信息也从公开版白皮书中消失了。该书描述了澳大利亚国防军关键人物和情报机构之间的激烈辩论。前者认为,澳大利亚需要作好与中国爆发冲突的准备,后者则表示,中国没有扩张野心,不大可能构成这样的威胁。公开版白皮书对战略环境和需要购买的军事装备进行了概述。这本新书说:“但文内并没有包括详细审视预料中的威胁以及为应对这些威胁澳大利亚所需的防务力量结构的绝密章节。”被删章节主要讲述的是澳大利亚和美国一起与中国打一场空海战的能力。相关计划涉及在远离中国的区域进行封锁,但目的是控制中国的海上航线,使其工业生产所依赖的自然资源的输送陷入停顿。白皮书说:“预计一个大国对手会对这些封锁作出反应,进行布雷和袭击港口。“国防部的部分想法是,如果与美国爆发冲突,中国将试图摧毁艾丽斯斯普林斯附近的美澳松峡信号设施。该设施对于指导美国在亚洲的军事行动至关重要......白皮书设想了一种截然不同的局势,在这个局势中,澳大利亚与美国在南中国海(以该地区为例)展开的联合海军作战行动可能导致中国直接袭击澳大利亚......“中国军力能达到5000公里以外并触碰到澳大利亚,这一能力是战略环境的一个新因素。”这就意味着澳大利亚需要一支能力大幅提高、能够进行远距离作战和本土防御的军队。尤伦指出,所有这些均未出现在公开版白皮书中,但公开版白皮书包含的很多信息加上媒体有关中国威胁的评论足以让北京领会其中的含意。在白皮书发表之前,时任澳大利亚总理陆克文派白皮书的主要作者、国防部官员迈克·佩苏略前往北京,向中国官员介绍白皮书的内容。佩苏略告诉中国国防部、外交部和军队的有关官员,澳大利亚媒体的报道强调了白皮书对中国军队现代化的评论,这些报道与澳政府无关。返回堪培拉后,佩苏略向美国使馆人员简要介绍了北京之行的情况。他告诉美国人,通过对白皮书的客观解读,中国人会发现这份文件根本没有提到“中国威胁”。中国媒体当时表示,白皮书是澳大利亚防务界“鹰派”的胜利,这在一定程度上是因为陆克文希望向选民表明,他在中国问题上同样持强硬立场,同时希望向美国表忠心,并为澳大利亚提供增加军力的借口。'

# %% [markdown]
# # 新词挖掘

# %% [markdown]
# ## 基于频次的新词挖掘

# %%
# 参考NLP-Series-NewWordsMining-PTMPretraining-main

# %%
from tqdm import tqdm

# %%
with tqdm(range(0, len(seg_texts), 1000)) as pbar:
    words = []
    for i in pbar:
        words.extend([word for text in seg_texts[i:i+1000] for word in text])
print(len(words))
# Out:
# 100%|██████████| 4/4 [00:00<00:00, 45.95it/s]
# 1520403

# %%
def get_chinese_words(file_path):
    with open(file_path, "r", encoding = "utf-8") as f:
        return [line.split()[0] for line in f.readlines()]

CH_DICT = set(get_chinese_words('./data/military_dict.txt'))

# %%
import re

unigram_freq, bigram_freq = {},{}
for i in range(len(words)-1):
    if words[i] not in CH_DICT and not re.search("[^\u4e00-\u9fa5]",words[i]): 
        if words[i] in unigram_freq: # 一阶计数
            unigram_freq[words[i]] += 1
        else:
            unigram_freq[words[i]] = 1
    bigram = words[i]+words[i+1]
    if bigram not in CH_DICT and not re.search("[^\u4e00-\u9fa5]",bigram): 
        if bigram in bigram_freq:
            bigram_freq[bigram] += 1
        else:
            bigram_freq[bigram] = 1

# %%
unigram_freq_sorted = sorted(unigram_freq.items(), key = lambda d: d[1],reverse = True)
bigram_freq_sorted = sorted(bigram_freq.items(), key = lambda d: d[1],reverse = True)

# %%
print("unigram:\n", unigram_freq_sorted[:100])
print("\n")
print("bigram:\n", bigram_freq_sorted[:100])
# Out:
# unigram:
#  [('的', 67969), ('在', 17855), ('了', 15853), ('和', 12746), ('是', 9632), ('中国', 5591), ('与', 5012), ('为', 4982), ('将', 4892), ('上', 4733), ('中', 4650), ('对', 4618), ('月', 4566), ('有', 4338), ('他', 4102), ('日', 4050), ('等', 4045), ('年', 3906), ('美国', 3884), ('也', 3822), ('官兵', 3795), ('说', 3271), ('进行', 3209), ('就', 3192), ('到', 3175), ('都', 3138), ('部队', 2809), ('我们', 2668), ('不', 2638), ('任务', 2595), ('一个', 2594), ('从', 2585), ('训练', 2444), ('时', 2394), ('后', 2391), ('并', 2362), ('被', 2358), ('我', 2329), ('工作', 2321), ('还', 2308), ('这', 2290), ('问题', 2282), ('发展', 2224), ('他们', 2153), ('要', 2133), ('报道', 2107), ('人', 2073), ('但', 2018), ('新', 2007), ('海军', 1988), ('记者', 1956), ('以', 1914), ('向', 1901), ('地', 1892), ('系统', 1843), ('国家', 1843), ('把', 1830), ('武警', 1813), ('航天员', 1780), ('组织', 1776), ('着', 1769), ('下', 1694), ('该', 1674), ('人民', 1672), ('军事', 1667), ('没有', 1666), ('而', 1572), ('能力', 1572), ('让', 1567), ('通过', 1542), ('安全', 1537), ('活动', 1532), ('作战', 1530), ('叙利亚', 1525), ('建设', 1490), ('日本', 1486), ('表示', 1462), ('自己', 1443), ('俄罗斯', 1435), ('个', 1413), ('会', 1388), ('装备', 1365), ('能', 1347), ('技术', 1336), ('其', 1330), ('据', 1326), ('更', 1318), ('飞行', 1284), ('这个', 1283), ('可以', 1277), ('多', 1275), ('报', 1263), ('计划', 1247), ('已经', 1219), ('支队', 1205), ('由', 1197), ('时间', 1190), ('又', 1185), ('号', 1163), ('导弹', 1146)]
#
#
# bigram:
#  [('人民武警', 1169), ('武警报', 1125), ('图片来源', 774), ('的是', 612), ('交会对接', 610), ('自己的', 601), ('进行了', 580), ('天宫一号', 577), ('上的', 559), ('神舟九号', 545), ('中国的', 534), ('也是', 516), ('中的', 493), ('都是', 472), ('新的', 464), ('他的', 436), ('任务的', 402), ('官兵的', 392), ('将在', 375), ('的问题', 362), ('我们的', 343), ('载人航天', 343), ('更多', 324), ('日在', 316), ('日报道', 310), ('是在', 310), ('这样的', 307), ('党的', 306), ('的一个', 306), ('的情况', 306), ('的重要', 298), ('美国的', 291), ('发展的', 289), ('过程中', 287), ('美国海军', 281), ('的能力', 280), ('的军事', 277), ('的人', 271), ('的工作', 271), ('有的', 264), ('到了', 261), ('他说', 260), ('的发展', 258), ('的时候', 256), ('情况下', 254), ('科学发展', 247), ('多的', 243), ('的中国', 241), ('重要的', 238), ('工作的', 235), ('的新', 234), ('部队的', 230), ('他们的', 229), ('有了', 227), ('问题上', 223), ('方面的', 222), ('国家的', 218), ('是一个', 218), ('年的', 216), ('的国家', 215), ('中国海军', 215), ('实现了', 213), ('新装备', 211), ('组织的', 210), ('举行的', 210), ('条件下', 209), ('报道称', 208), ('告诉记者', 208), ('三沙市', 207), ('人的', 205), ('是中国', 204), ('这一', 204), ('建设的', 204), ('了官兵', 204), ('特别是', 202), ('的安全', 201), ('介绍说', 200), ('将于', 199), ('都有', 198), ('的训练', 197), ('先进的', 196), ('系统的', 195), ('日上午', 194), ('问题的', 193), ('了一个', 193), ('最大的', 191), ('的基础', 190), ('的同时', 188), ('完成了', 188), ('我的', 183), ('就会', 180), ('之间的', 179), ('的时间', 173), ('战友们', 172), ('女航天员', 172), ('提供了', 171), ('美国在', 171), ('还将', 171), ('上合组织', 169), ('的目标', 169)]

# %%
for w in bigram_freq_sorted[:1000]:
    print(w[0])
# Out:
# 人民武警
# 武警报
# 图片来源
# 的是
# 交会对接
# 自己的
# 进行了
# 天宫一号
# 上的
# 神舟九号
# 中国的
# 也是
# 中的
# 都是
# 新的
# 他的
# 任务的
# 官兵的
# 将在
# 的问题
# 我们的
# 载人航天
# 更多
# 日在
# 日报道
# 是在
# 这样的
# 党的
# 的一个
# 的情况
# 的重要
# 美国的
# 发展的
# 过程中
# 美国海军
# 的能力
# 的军事
# 的人
# 的工作
# 有的
# 到了
# 他说
# 的发展
# 的时候
# 情况下
# 科学发展
# 多的
# 的中国
# 重要的
# 工作的
# 的新
# 部队的
# 他们的
# 有了
# 问题上
# 方面的
# 国家的
# 是一个
# 年的
# 的国家
# 中国海军
# 实现了
# 新装备
# 组织的
# 举行的
# 条件下
# 报道称
# 告诉记者
# 三沙市
# 人的
# 是中国
# 这一
# 建设的
# 了官兵
# 特别是
# 的安全
# 介绍说
# 将于
# 都有
# 的训练
# 先进的
# 系统的
# 日上午
# 问题的
# 了一个
# 最大的
# 的基础
# 的同时
# 完成了
# 我的
# 就会
# 之间的
# 的时间
# 战友们
# 女航天员
# 提供了
# 美国在
# 还将
# 上合组织
# 的目标
# 该支队
# 也有
# 中国载人
# 对中国
# 活动的
# 的任务
# 的官兵
# 联合军演
# 并不
# 提高了
# 航天员的
# 这是
# 的主要
# 都会
# 在轨
# 成了
# 航天工程
# 基础上
# 的要求
# 手控交会
# 的战略
# 它的
# 中国在
# 好的
# 与中国
# 是一种
# 国际社会
# 九号飞船
# 的方式
# 他在
# 就能
# 对接任务
# 高的
# 的技术
# 当地时间
# 的历史
# 护航编队
# 官兵在
# 两国
# 就在
# 的作战
# 地区的
# 教育活动
# 都要
# 岁的
# 等方面
# 的地方
# 在美国
# 出了
# 作战能力
# 该旅
# 在中国
# 在内的
# 宙斯盾
# 在南海
# 提出了
# 的思想
# 的作用
# 叙利亚问题
# 还在
# 组成的
# 个月
# 在太空
# 了中国
# 与天宫
# 中国航天员
# 与美国
# 训练的
# 据新华社
# 这也
# 的政治
# 的武器
# 进行的
# 海军的
# 的关系
# 是对
# 的创新
# 战士们
# 有可能
# 研制的
# 带着
# 军事文化
# 中国人
# 和军队
# 世界上
# 在该
# 并在
# 形成了
# 本报北京
# 月的
# 下的
# 结束后
# 领域的
# 尤其是
# 装备的
# 部队建设
# 取得了
# 训练中
# 都能
# 南海问题
# 防御系统
# 据了解
# 就有
# 的事
# 公司的
# 载人交会
# 任务中
# 印度海军
# 了新
# 创新理论
# 名航天员
# 的计划
# 武装直升机
# 技术的
# 的消息
# 天的
# 记者在
# 广大官兵
# 国家安全
# 后的
# 都在
# 组织官兵
# 军地
# 得到了
# 主要是
# 能力的
# 的飞行
# 将其
# 领导干部
# 带来的
# 就像
# 的实际
# 执行任务
# 的美国
# 载人潜水器
# 的精神
# 忠诚卫士
# 他还
# 也在
# 目的是
# 强大的
# 也不
# 举行了
# 良好的
# 航天员在
# 他们还
# 日下午
# 大的
# 内的
# 目标飞行器
# 的生活
# 是为了
# 让人
# 在叙利亚
# 的战斗
# 并将
# 是美国
# 参加了
# 的过程
# 让官兵
# 的变化
# 的部队
# 了自己
# 在这
# 的战士
# 可能会
# 开展了
# 使用的
# 日本的
# 的海军
# 资料图
# 批护航
# 飞机的
# 核心价值观
# 基层官兵
# 也将
# 不可能
# 建立了
# 发展成就
# 活动中
# 的目的
# 的影响
# 的飞机
# 不同的
# 对美国
# 上世纪
# 的方法
# 的行动
# 叙利亚的
# 的一次
# 是我们
# 的好
# 战争的
# 每一个
# 中国军队
# 的合作
# 了部队
# 弹道导弹防御
# 表彰为
# 可能是
# 在日本
# 和其他
# 的太空
# 文化活动
# 并没有
# 对其
# 他们在
# 导弹防御
# 叙利亚政府
# 据报道
# 特种作战
# 导弹的
# 在这个
# 可以在
# 的指挥
# 是个
# 这个支队
# 提出的
# 将是
# 发射的
# 美国和
# 的新型
# 和平使命
# 当代革命军人
# 被评为
# 的原则
# 军队的
# 时的
# 的导弹
# 政治工作
# 能在
# 人民的
# 在这里
# 等问题
# 的航天员
# 上了
# 了他
# 部署在
# 计划在
# 月中旬
# 革命军人核心
# 了解到
# 让我们
# 做了
# 同时也
# 该地区
# 直升机的
# 副部长
# 的一些
# 先进军事
# 为官兵
# 俄罗斯的
# 我们在
# 的特点
# 米级海试
# 在北京
# 在了
# 的力量
# 文化的
# 国家和
# 的成绩
# 日电据
# 出现了
# 的文化
# 在接受
# 米的
# 让他
# 范围内
# 在部队
# 的学习
# 个小时
# 日表示
# 取得的
# 有一个
# 新华社记者
# 文化建设
# 的海上
# 也没有
# 合作的
# 联合反恐
# 新华网北京
# 和美国
# 的基本
# 的优势
# 也会
# 战斗力生成
# 的和平
# 中国海监
# 被称为
# 的事情
# 个国家
# 计划的
# 多年来
# 蛟龙号
# 思想政治
# 的主权
# 出现在
# 日消息
# 提升了
# 综合报道
# 所有的
# 要在
# 但在
# 环太平洋
# 武装分子
# 两军关系
# 随军家属
# 是由
# 的信息
# 在与
# 亿美元的
# 标志着
# 增加了
# 副主任
# 信息化条件
# 单位的
# 日凌晨
# 海域的
# 安全的
# 感受到
# 的故事
# 的联合
# 行动的
# 的环境
# 更高
# 第一时间
# 的每
# 西方国家
# 其他国家
# 信息化建设
# 名官兵
# 激发了
# 日说
# 生产的
# 无人机的
# 发生的
# 历史上
# 就可以
# 年以来
# 巨大的
# 和中国
# 大家都
# 很好
# 将为
# 生活的
# 训练基地
# 支队官兵
# 对接的
# 与神舟
# 的最大
# 的机会
# 信息网报道
# 站在
# 飞控中心
# 解决了
# 就是要
# 防空导弹
# 的大
# 提供的
# 存在的
# 还能
# 增强了
# 她的
# 国防科技信息网
# 过硬的
# 领导的
# 要有
# 的经验
# 展示了
# 的第
# 面临的
# 并不是
# 采访时
# 上说
# 将继续
# 出来的
# 一个人
# 工作中
# 太空的
# 洛克利尔
# 在未来
# 的数据
# 在钓鱼岛
# 年开始
# 的空间
# 作战部队
# 下潜试验
# 赞颂科学
# 们的
# 每一次
# 前的
# 日电记者
# 监督团
# 的就是
# 钓鱼岛问题
# 力量的
# 的形式
# 武器的
# 出现的
# 生成模式
# 的说法
# 他们将
# 还没有
# 的研究
# 向叙利亚
# 让我
# 对叙利亚
# 由於
# 军队建设
# 的支持
# 最先进
# 已成为
# 已在
# 了对
# 又是
# 在阿富汗
# 达到了
# 使官兵
# 伦敦奥运会
# 有关部门
# 未来的
# 附近海域
# 我是
# 学习的
# 也要
# 做的
# 记者会上
# 现在的
# 将对
# 创造了
# 是我
# 伊朗的
# 时表示
# 的内容
# 稳定的
# 的国际
# 的国防
# 的努力
# 北京时间
# 美国将
# 据中国
# 一定要
# 飞行的
# 的需要
# 引导官兵
# 军人的
# 神舟八号
# 太空中
# 飞船的
# 叙利亚反对派
# 的他
# 的战友
# 中心的
# 的教育
# 反导系统
# 战机的
# 考虑到
# 梅德韦杰夫
# 促进了
# 首次载人
# 演练中
# 新华网消息
# 小时的
# 祖国的
# 多了
# 据美国
# 目标的
# 了大量
# 曾在
# 战场上
# 记者说
# 战斗精神
# 叙利亚危机
# 的各种
# 研究中心
# 的做法
# 俄罗斯和
# 来了
# 中俄
# 传统的
# 的一种
# 关系的
# 他是
# 项目的
# 发展好
# 先进单位
# 一号的
# 和发展
# 而不是
# 最重要
# 更好地
# 的原因
# 军演的
# 一定的
# 是他
# 我们要
# 阿基诺三世
# 有什么
# 要把
# 全面发展
# 使其
# 美国人
# 正在进行
# 该系统
# 将成为
# 日的
# 总设计师
# 的速度
# 的无人机
# 里的
# 今天的
# 的标准
# 海岸警卫队
# 发现了
# 是要
# 飞行任务
# 在他
# 你的
# 在天宫
# 的准备
# 会议上
# 作战的
# 的活动
# 的关键
# 的一部分
# 不仅是
# 训练和
# 的成功
# 但他
# 看到了
# 中队的
# 测控通信
# 群众的
# 人都
# 飞船与
# 保障能力
# 相关的
# 获得了
# 目前的
# 中国对
# 而在
# 并对
# 的设计
# 大量的
# 公里的
# 不断提高
# 是什么
# 早在
# 通过了
# 受到了
# 的热情
# 人民群众
# 神九
# 留下了
# 等活动
# 带来了
# 号航母
# 的相关
# 需要的
# 设计的
# 干部的
# 将被
# 有效的
# 演习的
# 这就是
# 的核心
# 新华社北京
# 使命的
# 的载人
# 对记者
# 主题教育
# 丰富的
# 战士的
# 少共国际
# 文化生活
# 都不
# 更大的
# 研发的
# 了许多
# 在国际
# 印度的
# 实战化
# 特殊的
# 间的
# 他表示
# 确保了
# 的建设
# 附属岛屿
# 政治教育
# 为部队
# 特战队员
# 的高度
# 真正的
# 介绍了
# 的行为
# 背景下
# 将与
# 环境下
# 了美国
# 新闻发言人
# 已经在
# 过的
# 对抗演练
# 通信系统
# 载人深潜
# 各单位
# 忠实履行
# 的表现
# 年轻的
# 把自己
# 某新型
# 掌握了
# 的忠诚
# 布拉莫斯
# 政府的
# 他就
# 战略轰炸机
# 找到了
# 的可能性
# 的报告
# 很可能
# 是世界
# 美军的
# 在亚太地区
# 的合同
# 有分析
# 的利益
# 了他们
# 的叙利亚
# 安全合作
# 可以说
# 在现场
# 联合演练
# 的形象
# 作出了
# 神舟飞船
# 拦截弹
# 国际师
# 航母的
# 月下旬
# 强烈的
# 赢得了
# 发挥了
# 也能
# 人员的
# 已经成为
# 很高
# 也都
# 在训练
# 信息化战争
# 该公司
# 变成了
# 下潜深度
# 能力素质
# 在一起
# 我就
# 比赛中
# 的比赛
# 新闻发布会
# 和战友
# 所需
# 的重点
# 都将
# 了这
# 我们将
# 完成任务
# 的唯一
# 在其
# 为确保
# 的重大
# 防空系统
# 日宣布
# 钓鱼岛的
# 也可以
# 都没有
# 仍在
# 合作组织
# 一直在
# 的状态
# 成立了
# 航天飞行
# 飞行乘组
# 自动交会
# 反政府
# 保障任务
# 这个旅
# 武器系统
# 的大型
# 的发射
# 了重要
# 的决定
# 的挑战
# 的具体
# 外交部发言人
# 会有
# 成功的
# 所谓的
# 社会的
# 的责任
# 号载人
# 与合作
# 的地区
# 是该
# 的理论
# 的声音
# 一号目标
# 革命卫队
# 才是
# 日本防卫
# 在今年
# 看到的
# 的组织
# 来的
# 装备了
# 文章称
# 的综合
# 则是
# 的时代
# 演习中
# 能力和
# 号的
# 一个重要
# 的帮助
# 人在
# 部队官兵
# 了我们
# 重要作用
# 关注的
# 这将
# 对伊朗
# 的态度
# 越来越多
# 菲律宾的
# 教育的
# 载人飞船
# 部队战斗力
# 较好
# 精神的
# 该基地
# 的航天
# 官兵和
# 连队的
# 国防和
# 的性能
# 的位置
# 专业的
# 在这种
# 这种情况
# 其在
# 战争中
# 过去的
# 中国和
# 美国国务卿
# 军事合作
# 分析人士
# 第十一批
# 的立场
# 上海合作
# 制定了
# 钓鱼岛及其
# 对他
# 航天员景海鹏
# 理论学习
# 最好的
# 我在
# 月上旬
# 军民融合
# 中国驻
# 一号与
# 了更
# 的经济
# 年后
# 的一天
# 大家的
# 和军事
# 国防部长帕内塔
# 认识到
# 南海的
# 的需求
# 了一些
# 与俄罗斯
# 有能力
# 例行记者会
# 和平与
# 它是
# 设备的
# 外的
# 级驱逐舰
# 都很
# 全面建设
# 开始了
# 的心理
# 北京航天飞行
# 飞行控制中心
# 记者看到
# 给他
# 他对
# 出的
# 发布会上
# 及其附属
# 的战争
# 附近的
# 的报道
# 要想
# 防卫省
# 更大
# 将进行
# 环境中
# 美国国防部长
# 国务卿希拉里
# 严重的
# 空军的
# 该项目
# 的所有
# 护航任务
# 还可以
# 美军在
# 的新闻
# 一体的
# 成为了
# 这对
# 发展和
# 经济发展
# 军事斗争
# 组织成员国
# 不知道
# 进入天宫
# 对接技术
# 引起了
# 部队在
# 既是
# 训练中心
# 警营文化
# 九号载人
# 听党指挥
# 环境的
# 这就
# 这个问题
# 说的
# 的压力
# 类似的
# 很有
# 的一项
# 的办法
# 多年的
# 积极的
# 美国总统
# 表达了
# 袭击事件
# 等地
# 的使命
# 全新的
# 这样一个
# 他们都
# 又有
# 唯一的
# 履行历史使命
# 也就是
# 一定会
# 的神舟
# 的话说
# 让他们
# 领导和
# 官兵对
# 指挥中心
# 海军官兵
# 新战士
# 潜艇兵
# 了一次
# 官兵思想
# 作为一名
# 建设和
# 的军队
# 召开的
# 利益的
# 最新的
# 刘为民
# 组织开展
# 了在
# 经历了
# 又一次
# 但由于
# 给了
# 发生了
# 了近
# 各项工作
# 已被
# 体系作战
# 叙利亚局势
# 全国人民
# 开展的
# 科学发展观
# 的某
# 新加坡共和国海军
# 履行使命
# 奠定了
# 在亚洲
# 中国与
# 更重要
# 一直是

# %% [markdown]
# ## 基于自由疑固度以及左右邻字熵的新词挖掘

# %% [markdown]
# - 自由疑固度：表示一个字串的凝固程度。
# <center>$$pmi(x,y) = log{\frac{P(x,y)}{P(x)P(y)}}$$</center>、
# - 左邻字熵与右邻字熵：表示一个字串左右搭配的丰富性。
# <center>$$entropy(w) = -P(x_i)logP(x_i)$$</center>
#
# **实战流程**
# 第一步：数据获取及预处理；词典获取；
# 第二步：将数据进行切分获取所有切分出的候选单词，并且统计词频信息、候选新词左右出现的字的信息；
# 第三步：根据第二步中统计的进行 pmi 值以及左右邻字熵的计算；
# 第四步：设定各指标的阈值，根据其值获取新词结果；
# 第五步：根据一些规则过滤掉明显不正确的新词，得到最终的新词结果。

# %% [markdown]
# ### 数据获取及预处理；词典获取

# %%
#全角转半角
def full_to_half(sentence):      #输入为一个句子
    change_sentence=""
    for word in sentence:
        inside_code=ord(word)
        if inside_code==12288:    #全角空格直接转换
            inside_code=32
        elif inside_code>=65281 and inside_code<=65374:  #全角字符（除空格）根据关系转化
            inside_code-=65248
        change_sentence+=chr(inside_code)
    return change_sentence

# %%
processed_texts = list(map(lambda s: full_to_half(s), processed_texts))

# %%
# 读取数据
from tqdm import tqdm
import re
    
def preprocess_data(lines):
    texts = []
#     with open(file_path, "r", encoding = "utf-8") as f:
#         lines = f.readlines()[:100000]
    with tqdm(lines, total=len(lines)) as pbar:
        for text in pbar:
#             text = re.sub("[^\u4e00-\u9fa5。？．，！：]", "", text.strip()) 
            text_splited = re.split("[。,？、．，！：]", text) 
#                 text_splited = ltp.sent_split([text])  # 调用LTP进行分句
            texts.extend(text_splited)
            
    tmp = texts
    texts = []
    with tqdm(tmp, total=len(tmp), desc="filtering the null sentences") as pbar:
        for text in pbar:
            if text is not "":
                texts.append(text)
    return texts
# Out:
# <>:20: SyntaxWarning: "is not" with a literal. Did you mean "!="?
# <>:20: SyntaxWarning: "is not" with a literal. Did you mean "!="?
# <ipython-input-211-fa9265b65136>:20: SyntaxWarning: "is not" with a literal. Did you mean "!="?
#   if text is not "":

# %%
texts = preprocess_data(processed_texts)
# Out:
# 100%|██████████| 3616/3616 [00:00<00:00, 41196.24it/s]
# filtering the null sentences: 100%|██████████| 191435/191435 [00:00<00:00, 2866054.34it/s]

# %%
# 获取已有的中文词典
def get_chinese_words(file_path):
    with open(file_path, "r", encoding = "utf-8") as f:
        return [line.split()[0] for line in f.readlines()]

CH_DICT = set(get_chinese_words('./data/military_dict.txt'))

# %% [markdown]
# ### 将数据进行切分获取所有切分出的候选单词，并且统计词频信息、候选新词左右出现的字的信息
#
# 接下来需要对文本进行切分以及获取相关的频次信息，这里统一在一个函数中，主要逻辑如下：
# - 对文本按照一定的长度范围进行切分，切分出所有成词的可能性，这里称之为字符串；
# - 对于所有切分出的字符串进行过滤，长度大于等于 2 的词以及不是词典 CH_DICT 中的词作为候选新词；
# - 获取所有切分出的字符串的频次信息（在后续计算中需要用到一些字符串的频次信息）、候选新词词频信息、候选新词左右出现的字的统计信息。

# %%
def get_candidate_wordsinfo(texts, max_word_len):
    '''
    texts：表示输入的所有文本
    max_word_len：表示最长的词长    
    '''
    # 四个词典均以单词为 key，分别以词频、候选新词词频、左字集合、右字集合为 value
    words_freq, candidate_words_freq, candidate_words_left_characters, candidate_words_right_characters = {},{},{},{}
    WORD_NUM = 0  # 统计所有可能的字符串频次
    with tqdm(texts, total=len(texts)) as pbar:
        for text in pbar:  # 遍历每个文本
            # word_indexes 中存储了所有可能的词汇的切分下标 (i,j) ，i 表示词汇的起始下标，j 表示结束下标，注意这里有包括了所有的字
            # word_indexes 的生成需要两层循环，第一层循环，遍历所有可能的起始下标 i；第二层循环，在给定 i 的情况下，遍历所有可能的结束下标 j
            '''貌似不对，最后几个词是不是多次重复了？？？'''
#             word_indexes = [(i,j) for i in range(len(text)) for j in range(i + 1, i + 1 + max_word_len)]
            '''修正'''
            word_indexes = [(i,j) for i in range(len(text)) for j in range(i + 1, min(i + 1 + max_word_len,len(text)+1))]
            WORD_NUM += len(word_indexes)
            for index in word_indexes:  # 遍历所有词汇的下标
                word = text[index[0]:index[1]]  # 获取单词
                # 更新所有切分出的字符串的频次信息
                if word in words_freq:
                    words_freq[word] += 1
                else:
                    words_freq[word] = 1
                if len(word) >= 2 and word not in CH_DICT:  # 长度大于等于 2 的词以及不是词典中的词作为候选新词
                    # 更新候选新词词频
                    if word in candidate_words_freq:
                        candidate_words_freq[word] += 1
                    else:
                        candidate_words_freq[word] = 1
                    # 更新候选新词左字集合
                    if index[0] != 0:  # 当为文本中首个单词时无左字
                        if word in candidate_words_left_characters:
                            candidate_words_left_characters[word].append(text[index[0]-1])
                        else:
                            candidate_words_left_characters[word] = [text[index[0]-1]]
                    else:
                        if word in candidate_words_left_characters:
                            candidate_words_left_characters[word].append(len(candidate_words_left_characters[word]))
                        else:
                            candidate_words_left_characters[word] = [0]                    
                    # 更新候选新词右字集合
                    if index[1] < len(text)-1:  # 当为文本中末个单词时无右字
                        if word in candidate_words_right_characters:
                            candidate_words_right_characters[word].append(text[index[1]]) # 
                        else:
                            candidate_words_right_characters[word] = [text[index[1]]]
                    else:
                        if word in candidate_words_right_characters:
                            candidate_words_right_characters[word].append(len(candidate_words_right_characters[word]))
                        else:
                            candidate_words_right_characters[word] = [0]
    return WORD_NUM, words_freq, candidate_words_freq, candidate_words_left_characters, candidate_words_right_characters

# %%
texts
# Out:
# ['南亚地区的权威军事来源称',
#  '巴基斯坦陆军进口了中国生产的CH-3A型攻击无人机',
#  '但是截至2012年',
#  '只进口了飞机本身',
#  '没有进口AR—1反坦克导弹',
#  '巴基斯坦陆军消息来源对加拿大《汉和防务评论》称',
#  '目前正在对CH—3进行测试',
#  '一旦效果理想',
#  '就会考虑进口AR—1反坦克导弹',
#  '报道称',
#  '巴基斯坦非常重视CH—3',
#  '目前还在考虑是否由巴基斯坦自己生产的可能性',
#  '相关的构思已经进行了较长时间',
#  'CH—3的最大航程2400公里',
#  '滞空时间12小时',
#  '中国陆军也在对CH—3进行测试',
#  'AR—1反坦克导弹重45公斤',
#  '射程8公里',
#  '惯性加GPS诱导',
#  '1.1马赫射速',
#  '其他权威消息来源还透露了更多的阿联酋进口“翼龙”攻击无人机的状况',
#  '这种无人机在后来的多次打靶过程中不太顺利',
#  '原因不明',
#  '中东地区的酷热天气可能影响了无人机与地面传感器之间的通信畅通',
#  '报道称',
#  '“翼龙”是成都飞机设计所(中航集团)设计',
#  '而武器系统是兵器工业集团的产品',
#  '也可能是两者在匹配方面出现了问题',
#  '“翼龙”的最大载弹量为200公斤',
#  '最大滞空时间20小时',
#  '[提要]在遂行非战争军事行动任务中',
#  '强化一切行动坚决听从党中央',
#  '中央军委指挥',
#  '非战争军事行动大多基于维护人民政权',
#  '维护国家安全',
#  '维护社会稳定和保障人民权益展开',
#  '从一定意义上讲打的是政治仗',
#  '接受的是政治考验',
#  '听党指挥是根本保证',
#  '必须坚持用党中央',
#  '中央军委决策指示统一思想',
#  '坚决服从统一组织指挥',
#  '严格区分和妥善处理两种不同性质矛盾',
#  '防止被别有用心的人利用',
#  '防止盲目行动而授人以柄',
#  '激化矛盾',
#  '胡锦涛同志反复强调',
#  '坚持党对军队绝对领导',
#  '是我军建设和发展的首要问题',
#  '是我军永远不变的军魂',
#  '任何时候任何情况下都不能有丝毫含糊和动摇',
#  '这一重大战略思想',
#  '抓住了国防和军队建设根本性全局性方向性问题',
#  '为我们更加坚定自觉地高举旗帜',
#  '听党指挥',
#  '履行使命提供了根本遵循和强大思想武器',
#  '在新形势下',
#  '必须把坚持党对军队绝对领导作为最高政治原则来把握',
#  '作为最高政治要求来落实',
#  '作为最高政治纪律来遵守',
#  '更加扎实地铸牢军魂',
#  '确保部队始终在思想上政治上行动上与党中央',
#  '中央军委保持高度一致',
#  '坚持用党的三代领导核心和胡锦涛同志重要论述统一思想',
#  '切实形成坚持党对军队绝对领导的高度自觉坚持党对军队绝对领导',
#  '是党的三代领导核心和胡锦涛同志建军治军的一贯思想',
#  '毛泽东同志鲜明提出',
#  '“我们的原则是党指挥枪',
#  '而决不容许枪指挥党”',
#  '邓小平同志反复告诫',
#  '军队要听党的话',
#  '“不能打自己的旗帜”',
#  '江泽民同志深刻指出',
#  '“一个军队要有军魂',
#  '我看',
#  '我们军队的军魂就是党的绝对领导”',
#  '胡锦涛同志多次强调',
#  '“要始终不渝坚持党对军队绝对领导的根本原则和制度',
#  '做到坚定不移听党指挥”',
#  '这些重要论述既一脉相承又与时俱进',
#  '深刻揭示了党对军队绝对领导的本质特征',
#  '鲜明反映了人民军队发展壮大的科学规律',
#  '继承发展了马克思主义军事理论的精髓',
#  '为我军坚持党的绝对领导奠定了坚实理论基础',
#  '长期以来',
#  '我军从小到大',
#  '由弱到强',
#  '不断从胜利走向胜利',
#  '最根本的就是始终坚持党的绝对领导',
#  '这是我军的建军之本',
#  '立军之基',
#  '强军之魂',
#  '在新形势下',
#  '随着军队建设所处时代条件和社会环境的发展变化',
#  '确保党对军队绝对领导面临新的考验和挑战',
#  '在新形势下铸牢军魂',
#  '坚持党对军队绝对领导',
#  '最根本的就是要深刻理解和把握党的三代领导核心和胡锦涛同志关于坚持党对军队绝对领导的一系列重要论述',
#  '不断深化对根本建军原则',
#  '基本军事制度',
#  '特有政治优势',
#  '敌我斗争焦点的认识',
#  '在新的思想高度形成政治自觉',
#  '历史自觉和实践自觉',
#  '必须清醒认识到',
#  '把党对军队绝对领导确立为我军根本建军原则',
#  '是由党的先进性决定的',
#  '是经过艰辛探索得出的真理性认识;坚持党对军队绝对领导',
#  '是党和国家的重要政治优势',
#  '有利于党巩固执政地位和提高执政能力',
#  '有利于国家长治久安',
#  '有利于保持我军性质宗旨和强大战斗力',
#  '原题:美智库教台军对付大陆两栖登陆战环球时报特约记者:在美国“重返亚太”的军事格局下',
#  '冷战中一度被赋予“不沉航母”身份的台湾该做些什么呢?美国企业研究所(AEI)最新发表的报告称',
#  '确保战时快速粉碎台湾意志并实施两栖登陆仍是解放军重要的斗争课题',
#  '与之相对应',
#  '对台军该如何反制大陆的“两栖闪电战”',
#  'AEI开出了所谓“不对称药方”',
#  '据台湾“中央社”6日报道',
#  '这项题为“平衡中的亚洲:美国在亚洲军事战略的转型”的报告是由前美国国防部官员卜大年(DanBlumenthal)与多名学者共同撰写',
#  '内容中有多处强调所谓“台海军力失衡”问题',
#  '进而引申出围绕“大陆对台动武门槛降低”的“担忧”',
#  '报告表示',
#  '中国大陆部署在福建',
#  '江西',
#  '广东的弹道导弹',
#  '即使在没有军事冲突发生的情形下',
#  '也足以在关键时刻动摇美国及其盟友援台的信心',
#  '报告尤其点了解放军发展的东风-21D反舰弹道导弹的名',
#  '该导弹据说赋予解放军在距岸1500公里外打击海上机动舰队的能力',
#  '特别是对美国航母构成严重威胁',
#  '成为中国大力构建“反介入/区域隔离”作战系统的王牌',
#  '不仅如此',
#  '中国大陆未来还将发展射程更远的反舰弹道导弹',
#  '从而进一步驱美国航母于台湾之外',
#  '报告提到',
#  '解放军正在部署更多配备反舰巡航导弹的潜艇',
#  '虽然它们的性能尚无法与美国及其盟友媲美',
#  '但结合数量优势',
#  '利用“蜂群战术”也足以令对手疲于奔命',
#  '东方网消息:5月30日',
#  '俄罗斯《军工信使》周刊报道称',
#  '据非正式消息透露',
#  '目前中国已经从瑞典成功采购了供其航母使用的拦阻索',
#  '而且还以西方技术为基础',
#  '研制出了中国国产电磁弹射器',
#  '以便代替蒸汽弹射器',
#  '报道指出',
#  '继中国领导人强调每个大国都应该拥有航母后',
#  '有关部门便开始实施海军航母建设计划',
#  '早期时候',
#  '中国通过购买原苏联退役航母的方式',
#  '来研究航母相关技术:它先是于1997年得到了“明斯克”号',
#  '后又在2000年获得了“基辅”号',
#  '再后来便是“瓦良格”号',
#  '其中',
#  '“瓦良格”号在运往中国的途中',
#  '遭到了土耳其的强烈阻挠——由于担心中国可能会把未完工的这艘航母建成真正的航母',
#  '从而掌握航母技术',
#  '所以美国决定对土耳其施压',
#  '要求其阻止“瓦良格”号通过黑海海峡',
#  '结果',
#  '中国外长不得不访问土耳其进行直接干预',
#  '才使得该问题得以解决',
#  '2001年',
#  '“瓦良格”驶出黑海',
#  '它于2002年3月地道大连造船厂等待接受改装',
#  '《澳大利亚人报》网站6月2日报道题:澳中秘密“战”曝光陆克文政府2009年国防白皮书的一个秘密章节详细介绍了澳大利亚与中国打一场战争的计划',
#  '根据该计划',
#  '澳大利亚海军潜艇将帮助封锁中国的贸易线路',
#  '而中国可能会向澳大利亚目标发射导弹进行报复',
#  '据新书《王国与资源:中国',
#  '澳大利亚',
#  '恐惧与贪婪》透露',
#  '白皮书提出的军力2030——将包括12艘装备导弹的大型常规潜艇',
#  '革命性的联合攻击战斗机',
#  '防空驱逐舰和巨型登陆舰——正在筹建之中',
#  '以应对可能发生在澳大利亚与其主要贸易伙伴之间的战争',
#  '在2009年5月白皮书发表前夕',
#  '本报曾对澳大利亚各安全和情报机构间展开的辩论进行过广泛报道',
#  '当时它们辩论的话题是:中国不断增加对武装力量的投入',
#  '是否会构成威胁',
#  '公开版的白皮书没有宣称报告作者担心与中国爆发战争',
#  '为了避免冒犯中国',
#  '并让官员们有某种程度的推诿余地',
#  '有关未来可能爆发冲突的讨论使用了诸如一个“大国对手”这样的委婉语',
#  '新书的作者',
#  '本报经济栏目主编戴维·尤伦还透露',
#  '有关方面曾向财政部施加巨大压力',
#  '要求其为大量新型装备编制详细预算',
#  '但大部分相关信息也从公开版白皮书中消失了',
#  '该书描述了澳大利亚国防军关键人物和情报机构之间的激烈辩论',
#  '前者认为',
#  '澳大利亚需要作好与中国爆发冲突的准备',
#  '后者则表示',
#  '中国没有扩张野心',
#  '不大可能构成这样的威胁',
#  '公开版白皮书对战略环境和需要购买的军事装备进行了概述',
#  '这本新书说:“但文内并没有包括详细审视预料中的威胁以及为应对这些威胁澳大利亚所需的防务力量结构的绝密章节',
#  '”被删章节主要讲述的是澳大利亚和美国一起与中国打一场空海战的能力',
#  '相关计划涉及在远离中国的区域进行封锁',
#  '但目的是控制中国的海上航线',
#  '使其工业生产所依赖的自然资源的输送陷入停顿',
#  '白皮书说:“预计一个大国对手会对这些封锁作出反应',
#  '进行布雷和袭击港口',
#  '“国防部的部分想法是',
#  '如果与美国爆发冲突',
#  '中国将试图摧毁艾丽斯斯普林斯附近的美澳松峡信号设施',
#  '该设施对于指导美国在亚洲的军事行动至关重要......白皮书设想了一种截然不同的局势',
#  '在这个局势中',
#  '澳大利亚与美国在南中国海(以该地区为例)展开的联合海军作战行动可能导致中国直接袭击澳大利亚......“中国军力能达到5000公里以外并触碰到澳大利亚',
#  '这一能力是战略环境的一个新因素',
#  '”这就意味着澳大利亚需要一支能力大幅提高',
#  '能够进行远距离作战和本土防御的军队',
#  '尤伦指出',
#  '所有这些均未出现在公开版白皮书中',
#  '但公开版白皮书包含的很多信息加上媒体有关中国威胁的评论足以让北京领会其中的含意',
#  '在白皮书发表之前',
#  '时任澳大利亚总理陆克文派白皮书的主要作者',
#  '国防部官员迈克·佩苏略前往北京',
#  '向中国官员介绍白皮书的内容',
#  '佩苏略告诉中国国防部',
#  '外交部和军队的有关官员',
#  '澳大利亚媒体的报道强调了白皮书对中国军队现代化的评论',
#  '这些报道与澳政府无关',
#  '返回堪培拉后',
#  '佩苏略向美国使馆人员简要介绍了北京之行的情况',
#  '他告诉美国人',
#  '通过对白皮书的客观解读',
#  '中国人会发现这份文件根本没有提到“中国威胁”',
#  '中国媒体当时表示',
#  '白皮书是澳大利亚防务界“鹰派”的胜利',
#  '这在一定程度上是因为陆克文希望向选民表明',
#  '他在中国问题上同样持强硬立场',
#  '同时希望向美国表忠心',
#  '并为澳大利亚提供增加军力的借口',
#  '新加坡《海峡时报》6月4日文章',
#  '原题:棘手问题制约中国潜艇战略解放军于上世纪80年代下水“夏”级弹道导弹核潜艇',
#  '但航速缓慢',
#  '噪音偏大',
#  '性能不稳定的“夏”级极易受到攻击',
#  '为解决这些问题',
#  '中国推出新型“晋”级战略核潜艇和“巨浪-2”型弹道导弹',
#  '目前已有两艘“晋”级交付使用',
#  '至少还有两艘在建',
#  '然而',
#  '要想将这些资产转化为二次打击能力',
#  '北京至少还面临两个重大问题',
#  '一是技术问题',
#  '二是更严肃的政治问题',
#  '技术方面包括通信能力',
#  '五角大楼两年前出台的报告称',
#  '解放军海上潜艇通信能力有限',
#  '也无管理执行战略巡航任务的核潜艇舰队的经验',
#  '简言之',
#  '中国的潜艇在海下潜航时无法与总部进行通信联系',
#  '它们需浮出水面或放出通信浮标',
#  '这两种做法会令其易于被发现和遭攻击',
#  '一名熟悉该领域的人士表示',
#  '解决这个问题不容易',
#  '但最终会被克服',
#  '但在此之前',
#  '解放军甚至无法有效训练核潜艇进行战略巡逻',
#  '该人士表示',
#  '另一方面还存在命令控制问题',
#  '即政治约束',
#  '陆基系统是中国核武库的主要组成部分',
#  '弹头和导弹被分离存放',
#  '它们受到高度集中体系的控制',
#  '从中央军委到中央政治局',
#  '再到总参谋部和二炮总部',
#  '最后才是承担发射责任的战斗部队',
#  '而核潜艇巡逻需同时装备弹头和导弹',
#  '关键决策权力应掌握在海军军官手中',
#  '这是北京从不允许的',
#  '美国防长帕内塔在新加坡香格里拉论坛上重申美国“战略东移”',
#  '并宣布美国战舰的60%将部署到太平洋',
#  '他同时否认此举意在遏制中国',
#  '他的否认虽然很可能不是“100%的假话”',
#  '但全世界都不会有人敢把它当真话听',
#  '还是说“战略东移”吧',
#  '美国喊它不只一年两年了',
#  '随着中国崛起',
#  '谁在美国的位置上大概都会这样做',
#  '中国既然要发展',
#  '就得承受这个压力',
#  '中国带来了世界格局的深刻变化',
#  '这种变化令很多力量惴惴不安',
#  '他们的不安会转化成一些行动',
#  '最终压力都会返回到中国',
#  '客观而言',
#  '美中目前的博弈方式是人类历史上霸权国同崛起国之间最文明的',
#  '中国对利益范围扩大的处理很克制',
#  '美国也未因防范中国而公开撕破脸皮',
#  '现在要防止两国对最坏情况的准备成为中美关系的主导内容',
#  '从中国方面说',
#  '我们需要针对美国的部署做认真的反部署',
#  '但不应一提中美关系想的就是这件事',
#  '从长远看',
#  '美国有可能把更多军事力量部署到亚太',
#  '那又怎么样?中国必须像美国人说的那样',
#  '最终拥有在近海的绝对反介入能力',
#  '包括反航母能力',
#  '美国航母在中国周边海域的实际威慑力只会越来越低',
#  '除此之外',
#  '中国应有足够的信心',
#  '中国崛起是挡不住的',
#  '其实美国搞战略东移也是对中国崛起没有办法时的无奈安排',
#  '有自我安慰的因素',
#  '中国崛起的内容如此丰富',
#  '怎么可能是调动几只军舰就能遏制的',
#  '如果真那样',
#  '未来的国际关系倒会简单得多',
#  '中国将在未来很多年里劣势于美国',
#  '中国的结盟能力也将大大逊于美国',
#  '中国前进一步',
#  '来自美国的压力就会上一个等级',
#  '如果美国仅仅搞些“小动作”',
#  '我们就感觉压抑得喘不过气',
#  '那我们就应该趁早向西方屈服',
#  '华盛顿怎么说我们就怎么做',
#  '中国没必要对美国硬碰硬',
#  '或者说硬碰硬是中国与美周旋的下下策',
#  '中国的上策是让美国的军事部署派不上用场',
#  '而把两国的博弈尽量朝中国力量增长更快的方向引',
#  '中美经济的发展趋势是你中有我',
#  '我中有你',
#  '这种搅成一团的拉扯对弱的一方更有利',
#  '中美目前没有直接军事冲突的紧迫威胁',
#  '但都对它的出现有所担心',
#  '这种担心不应被刻意转变成存心要打一仗',
#  '以此证明自己国家“有力量”或者“有骨气”的愿望',
#  '但这些不意味着中国可以允许美国的对华防范性部署肆无忌惮',
#  '中国需要多探索一些阻止美国介入的方法',
#  '并为此做不厌其烦的细致工作',
#  '从而增加美国部署的地缘政治和地缘经济成本',
#  '令其投鼠忌器',
#  '我们必须清楚',
#  '崛起时代的中国安全是很昂贵的',
#  '中国保持和平',
#  '有可能不比打仗的经济成本更低',
#  '为阻止美国的“战略东移”在中国周边扎根',
#  '彻底改变亚洲的国际关系环境',
#  '中国就得准备做些付出',
#  '美国直接用军事力量摧毁以中国崛起为中心的亚太运行图的可能性很小',
#  '但美国会利用军事压力造势',
#  '扰乱亚太国家对局势的判断',
#  '制造中国犯错误的机会',
#  '如果中国发展不下去',
#  '表层原因将五花八门',
#  '但美国的遏制将是根源性缘由之一',
#  '中国不与美国斗力',
#  '要斗智慧',
#  '斗胸怀',
#  '斗坚持',
#  '中国的体量这么大',
#  '遏制中国根本无从下手',
#  '时间一年年过去',
#  '光是中国市场的逐渐变大带给世界的好处',
#  '就能帮我们大忙',
#  '中美的博弈形势决不仅仅看谁在太平洋的军舰多',
#  '据悉',
#  '韩军2017年起引进的登陆机动直升机32架将部署由海军陆战队',
#  '这样',
#  '韩海军陆战队44年后将重新获得到航空战力',
#  '据韩军方消息人士透露',
#  '登陆机动直升机引进项目(40架直升机)中第一批引进的32架直升机将部署海军陆战队',
#  '在4日召开的军务会议上',
#  '将就上述内容做出',
#  '韩军2005年起启动了登陆机动直升机引进项目',
#  '海军方面主张',
#  '登陆作战也是海军作战的一环',
#  '因此',
#  '将陆机动直升机部署海军才是最为高效',
#  '最为明智的选择',
#  '海军陆战队方面则声称',
#  '应该直接部署于执行登陆作战的海军陆战队',
#  '这样才更有利于作战行动的迅速展开',
#  '因为双方意见严重对立',
#  '所以一直未能做出具体决定',
#  '至于剩下的8架究竟部署何处',
#  '尚未做出最后定论',
#  '韩军计划让海军第六航空战团和陆军航空作战司令部帮助海军陆战队完成好飞行员的教育训练及直升机维护保养工作',
#  '海军陆战队1958年成立海军陆战队航空队',
#  '1973年海军陆战队司令部解体后',
#  '所有人员及装备全部移交海军',
#  '1987年海军陆战队重新成立',
#  '但航空部队一直未能组建',
#  '知远/珠峰',
#  '5月下旬的一天',
#  '海军某猎潜艇大队3艘舰艇组成的反潜编队经过两昼夜连续航行',
#  '伴着夜色驶入某海域',
#  '突然',
#  '指挥艇接到上级命令:“在距你编队××海里的海域有不明潜艇活动',
#  '命你编队火速前往搜索攻击!”一次夜间反击潜艇行动',
#  '在某陌生海域悄悄拉开战幕——18时15分',
#  '编队各艇按战斗航向进入指定海域',
#  '此时',
#  '海面风疾浪高',
#  '天空下起瓢泼大雨',
#  '气象条件异常恶劣',
#  '战艇时而被推上浪尖',
#  '时而掉进波谷',
#  '突然',
#  '编队指挥艇声呐兵报告:“艇艏方向出现轻微回音后消失',
#  '”急促的战斗警报声响起',
#  '3艘猎潜艇迅速成单纵队加速前进',
#  '形成一条数海里的封锁线',
#  '两分钟后',
#  '几乎在同一方位',
#  '再次报告有“敌”潜艇回音',
#  '但信号较弱',
#  '编队指挥员',
#  '某猎潜艇大队大队长段见云判断',
#  '“敌”潜艇已发现我编队行踪',
#  '企图从编队前方逃窜',
#  '他迅速指挥编队改变航向航速',
#  '一张猎“鲨”大网悄然撒开',
#  '不到5分钟',
#  '各艇相继报告:“发现目标',
#  "'敌'艇已转向!”段见云一声令下",
#  '从不同方向',
#  '不同距离模拟发射的数十枚火箭深弹直奔目标',
#  '一条“黑鲨”中弹后在不远处浮出水面',
#  '反潜编队正准备返航',
#  '再次接到上级命令:发现“敌”另一目标藏匿于附近海域!编队在夜海中劈浪挺进',
#  '声呐兵双眼紧盯显示屏',
#  '仔细辨别每一个目标回波',
#  '5分钟',
#  '10分钟......半个小时过去了',
#  '目标却始终没有出现',
#  '指挥员段见云根据“战场”态势判定',
#  '“敌”潜艇可能处于我编队声呐回波盲区',
#  "“编队成'Y'队形搜索扇面",
#  '扩大搜索范围',
#  '”段见云果断下达命令',
#  '随着编队变阵',
#  '声呐部位传来强烈回波',
#  '正符合“黑鲨”信号特征',
#  '指挥艇率先判定目标方位',
#  '另外两艘艇也相继传来“锁定目标”的报告',
#  '经过近两个小时的较量',
#  '“敌”潜艇一直被反潜编队牢牢锁定在攻击范围之内',
#  '不得不浮出水面......',
#  '环球网报道:据日本新闻网6月13日消息称',
#  '日本防卫省计划将向黄海海域部署宙斯盾舰',
#  '以及高性能侦察机',
#  '据称',
#  '日防卫省这一军事部署计划将于本周内提交日新任防相森本敏进行审议',
#  '日防卫省透露消息称',
#  '部署日本海上自卫队宙斯盾舰进入黄海',
#  '目的是为了应对朝鲜核开发',
#  '报道称',
#  '2012年4月',
#  '朝鲜曾发出即将发射人造卫星的预告后',
#  '日本政府曾出动3艘宙斯盾舰',
#  '并将其部署在日本列岛与朝鲜半岛之间的日本海地区',
#  '以及朝鲜火箭有可能穿越的日本冲绳附近海域',
#  '但朝鲜卫星发射后',
#  '搭载有先进雷达系统的日海自宙斯盾舰并未能探测到朝鲜卫星的发射信息',
#  '日本最终在美韩两国发布消息后才得到朝鲜火箭已经解体的情报',
#  '因此',
#  '日本防卫省认为',
#  '日海自宙斯盾舰由必要直接进入中国与朝鲜之间的黄海海域',
#  '近距离“监视”朝鲜的核开发和导弹试射动向',
#  '同时',
#  '搭载有红外侦察传感器(ISR)的侦察机也将投入到黄海地区进行侦察任务',
#  '日本新闻网报道分析认为',
#  '黄海是中国北海舰队基地所在海域',
#  '同时也是中国“瓦良格”号航母海试的主要海域之一',
#  '因此',
#  '日本当局的这一军事部署计划是否有“一石二鸟”的企图值得怀疑',
#  '分析指出',
#  '2011年',
#  '美国舰队曾进入黄海海域',
#  '引起中方强烈不满',
#  '也导致中美两军的严重对峙',
#  '对此',
#  '日本防卫当局应当“心知肚明”',
#  '如果日本最终在黄海实施这一军事部署',
#  '必将引起中日两国的军事紧张局势',
#  '同时或直接导致中日钓鱼岛问题的进一步复杂化',
#  '据称',
#  '日本这一军事部署计划将于本周内提交新任防相森本敏审议',
#  '并极有可能获得通过',
#  '6月3日下午',
#  '由中国北方国际射击场主办的“我是小冠军——庆六一',
#  '第六届未来之星射击赛”圆满结束!本次活动历时三天',
#  '共产生一等奖一名',
#  '二等奖五名',
#  '三等奖十一名',
#  '优胜奖若干',
#  '正所谓“国无防不立',
#  '民无防不安”',
#  '国防教育与每一个公民息息相关',
#  '青少年是祖国的栋梁',
#  '是未来国防建设的中坚力量',
#  '因此',
#  '面向青少年开展国防教育',
#  '树立强烈的爱国主义意识至关重要',
#  '为了使青少年能够掌握基本的国防知识',
#  '学习必要的军事技能',
#  '了解射击这项体育运动',
#  '中国北方国际射击场特举办此次活动',
#  '“我是小冠军——庆六一',
#  '未来之星射击赛”在昌平区旅游局',
#  '昌平区教委',
#  '昌平区体育局等单位领导的关心和支持下已成功举办了六届',
#  '参赛选手已达到近千人',
#  '活动项目不仅包括EM-332运动步枪的射击',
#  '而且参赛的小朋友都可以在家长的陪同下参观轻武器博物馆',
#  '轻武器博物馆是目前国内唯一一家专业的轻武器博物馆',
#  '馆内陈列了从冷兵器时代开始到古',
#  '近代热兵器',
#  '再到现代热兵器各个时期典型的轻武器',
#  '囊括了枪械系统',
#  '榴弹武器',
#  '单兵制导武器等轻武器类型',
#  '而且中国厅展出的轻武器是国内最齐全的',
#  '活动主要强调趣味性和竞技性相结合',
#  '希望在寓教于乐的同时',
#  '拓宽小朋友们国防方面的相关知识',
#  '丰富大家的课余文化生活!',
#  '118年前',
#  '中日海军激战黄海',
#  '史称“甲午海战”',
#  '凭借该次战争的胜利',
#  '日本彻底赢得了黄海制海权',
#  '强迫中国清朝政府签订了丧权辱国的《马关条约》',
#  '118年后',
#  '日本舰艇准备再入黄海',
#  '只不过',
#  '日本这次为自己寻找的理由是:防范朝鲜再发导弹',
#  '5月30日',
#  '日本《朝日新闻》的一篇报道曝光了日本防卫省已经整理完毕的一份报告',
#  '这一报告明确表示',
#  '今后如果朝鲜再进行疑似导弹试验的卫星发射',
#  '海上自卫队将派遣宙斯盾舰前往“发射地点周边海域”',
#  '虽然在报告中没有明确写出“黄海”海域',
#  '但防卫省内部人士表示',
#  '报告中的“周边海域”就是指“黄海”',
#  '而且设定的地点就在黄海南部',
#  '关注日本军情动态的人们会发现',
#  '尽管日本的防卫相关经费已经连续十年下降',
#  '但是',
#  '近年来它的军事动作却日趋频繁',
#  '从海湾战争自卫队“出兵”伊拉克',
#  '到派遣军舰前往索马里海域护航;从在吉布提建立首个海外军事基地',
#  '到与美军共同使用菲律宾基地设施;从放宽“武器出口三原则”到向菲律宾',
#  '越南等国家提供武装舰只',
#  '日本在一步步扩大自己的国际军事影响力和活动范围',
#  '而且在每一步都不忘为自己的行动寻找借口',
#  '提供法律依据',
#  '分析起来',
#  '日本近些年来加紧“战备”行动',
#  '是由内外两方面因素促成的',
#  '首先',
#  '美国的支持与纵容',
#  '使日本有胆量加速“走出去”的步伐',
#  '“二战”后',
#  '在美国的监控下',
#  '日本制订了《和平宪法》',
#  '美国借此对日本的军事发展进行严格的限制',
#  '但其实美国并没有完全扼杀日本的军工发展',
#  '只是要“养犬为恶”',
#  '美国近几年出现经济衰退后',
#  '这个一心想打造单极世界的超级大国在执行对外军事行动时',
#  '也显得有些力不从心',
#  '在这种情况下',
#  '美国采用的“新战争”模式就是最低限度地投入自身兵力',
#  '同时最大程度地利用同盟国的军事力量',
#  '如果说美国过去多是在经济方面利用日本',
#  '那么',
#  '如今美国还希望日本在地区政治和军事上给予自己更大的协助',
#  '在日本推行“价值观外交”拉拢中国周边国家大搞“遏华”包围圈的活动中',
#  '在日本加紧建设大范围反导系统的行动中',
#  '在日本积极援建菲律宾对抗中国的举措中',
#  '都可以发现美国暗中指挥的踪影',
#  '其次',
#  '虽然“二战”后制订了《和平宪法》',
#  '取消了军队改称自卫队',
#  '但日本国内的好战势力时刻也没有停止对外扩张的努力',
#  '这从近些年来日本国内一浪高过一浪的企图“修宪建军”的呼声中',
#  '从一次次《防卫大纲》内容的变化中',
#  '以及某些政客肆无忌惮的言语中',
#  '都清晰地体现出来',
#  '然而',
#  '谙熟中国兵家之法的日本人很明白',
#  '向外扩张绝不可“师出无名”',
#  '为此',
#  '他们逮住任何时机',
#  '想尽一切办法',
#  '为自己的军事行动寻找理由',
#  '制造借口',
#  '除了借用日美同盟为幌子',
#  '编造“中朝威胁论”是他们惯用的伎俩',
#  '今年4月朝鲜卫星发射前夕',
#  '日本曾派3艘宙斯盾舰在日本海和东海执行监视任务',
#  '但是',
#  '在朝鲜卫星发射后',
#  '日本未能及时掌握有关信息',
#  '野田内阁和防卫省遭到各方质疑',
#  '民众信任度下降',
#  '而这原本为失误的行为竟成了日本准备派遣军舰进入黄海的理由',
#  '因为他们坚称',
#  '黄海是监视朝鲜导弹行踪的最佳位置',
#  '而在今年早些时候',
#  '日本还决定',
#  '将把“网络攻击”视同“武力攻击”',
#  '即在日本国内网络遭遇来自国外的病毒攻击时',
#  '就视为日本遭到国外的“武力攻击”',
#  '就可以合法地使用“网络武器”还击',
#  '从而为日本发动“网络战争”制造了合理借口',
#  '日本防卫省的消息人士透露',
#  '为了顺利向黄海派遣宙斯盾舰',
#  '日本外务省准备与中国协商',
#  '而人们看到的是',
#  '日本这几年在“小步快跑”的行动中',
#  '也在暗中试探亚洲国家的反应',
#  '这种不断为其军事行为寻找理由的行径',
#  '应当引起人们的关注和警惕',
#  '东方网记者报道:据日本共同社报道',
#  '驻日美国海军3月向媒体展示了部署于神奈川县厚木基地的最先进电子战机EA-18G',
#  'EA-18G是世界上最先进的电子战机',
#  '能百分之百地完成任何电子干扰压制任务',
#  '它机身上的相控阵雷达可以摧毁敌方的电子设备',
#  '可通过电子仪器进行侦查',
#  '并对敌机实施电子干扰',
#  '更重要的是',
#  '美军09年亮相的一架该型战机的机身上',
#  '醒目地标有一架F-22图案',
#  '这说明该机曾击落过目前世界上最先进的第四代战机F-22',
#  '因此',
#  'EA-18G可称为“王中之王”',
#  '目前',
#  '关岛等美军亚太岛链部署的重点地域以及巡弋于海上的航母都有可能成为EA-18G的立足之地',
#  '前沿部署',
#  '海上移动平台加上EA-18G从“大黄蜂”身上继承过来的1000公里作战半径',
#  '再考虑机载的各种电子战系统的电子作战范围',
#  '亚洲大陆近海雷达与电子设备将尽在EA-18G威胁之下',
#  '美军电子战力逼近亚太直指解放军',
#  '有台湾专家表示',
#  '在实施电子战的硬件方面',
#  '解放军与美军的差距并不大',
#  '但就整体素质而言',
#  '差距高达20年甚至更多',
#  '问题就在于:一些由中国独立研发的电子作战设备尚未全面装备部队',
#  '这是一群海防工程建设的幕后英雄:他们用先进的设计理念',
#  '圆满完成5000多项海防工程勘察设计任务',
#  '在我国辽阔的海岸线上矗立起一座座雄关如铁的海军战备工程',
#  '这是一支功勋卓著的科研劲旅:他们用艰辛和智慧',
#  '为海军第一个大型舰艇基地',
#  '全军最大的高桩码头',
#  '我国第一个岛礁机场描绘蓝图',
#  '创造出30多项全国第一',
#  '60多项全军之最',
#  '他们就是海军某工程设计局的科研人员',
#  '被誉为“海上长城的工程师”',
#  '精益求精:“误差如超过2毫米',
#  '我们就是历史的罪人”“人们都拿绣花比喻精细',
#  '可我们这个工程需要的精度比绣花还要细!”回忆起数年前那一幕',
#  '防护工程设计室主任王全胜异常激动',
#  '某军港战备工程',
#  '其关键环节安装精度要求控制在2毫米以内',
#  '当时',
#  '许多业内专家都投了“否决票”:加工制作',
#  '运输',
#  '焊接',
#  '季节温差等可能影响安装精度的因素太多',
#  '任何一个环节出现细微差错',
#  '都将会前功尽弃!关键时刻',
#  '他们挺身而出',
#  '出征大会上',
#  "大家众志成城:“这个'山头'必须拿下",
#  '误差如超过2毫米',
#  '我们就是历史的罪人!”炎炎夏日',
#  '南海之滨',
#  '项目组长李忠平带领大家俯身在密闭的集装箱里',
#  '布设密如蛛网的线路进行技术试验',
#  '整整两个月',
#  '他们的衣服每天都被汗水浸泡着',
#  '失败了',
#  '从头再来......他们先后推翻了30多种方案',
#  '终于测得了最精准的数据',
#  '紧接着',
#  '分段裁剪',
#  '拼接安装......经过700多个日日夜夜的奋战',
#  '他们如期完成了这一任务',
#  '竣工这一天',
#  '李忠平体重减轻了10公斤',
#  '白发多了许多......“工程设计是工程建设的基准',
#  '必须精益求精',
#  '不容任何瑕疵',
#  '”如今',
#  '该局科研人员不仅把这句话挂在嘴上',
#  '还时刻落实在行动中',
#  '精心设计每一张图纸',
#  '那年',
#  '试验某防波堤工程',
#  '为使设计的工程经受住台风冲击',
#  '高工张华昌在试验大厅水池中进行波浪模拟测试',
#  '当时',
#  '试验水温只有4℃左右',
#  '冻得他浑身发抖',
#  '嘴唇发紫',
#  '张华昌丝毫没有因此放低标准',
#  '经过反复试验',
#  '分析对比',
#  '最终推出最优的设计方案',
#  '俄罗斯新大陆网站6月1日文章',
#  '原题:中国武装起来',
#  '美国担忧在中国军事实力快速增长的背景下',
#  '美国担心中国在亚太地区拥有政治和军事优势',
#  '为此',
#  '它扩大在该地区的军事存在',
#  '实际上',
#  '美国人不应该责怪中国对其充满敌意',
#  '中美关系近期紧张主要是由1月美国国防部公布《保持美国全球领导能力:21世纪国防重点》新军事战略报告引发的',
#  '报告重点强调中国在亚太地区对美国的威胁',
#  '并决定将战略重点转向亚太',
#  '加强对中国的遏制',
#  '这表明中国应担心美国',
#  '而不是美国担心中国',
#  '对于中国军费的增长',
#  '美国传统基金会亚洲安全问题专家程迪恩(音)表示',
#  '这主要是因为:对防御力量的担忧',
#  '包括邻国对领土的觊觎及保护贸易线路;配备现代化军事技术装备;进行高质量军队改革;购买先进武器价格昂贵',
#  '专家指出',
#  '美国应当担忧的不应是中国军费的增长',
#  '而是中国获得对美实施非对称作战系统',
#  '这才是让美国最为恐惧的',
#  '德国波恩大学全球研究中心主任古休埃乌表示',
#  '中国军费占GDP的比重不到2%',
#  '且根本无法与美国军费相提并论',
#  '中国军队的当务之急是缩小与世界先进国家的技术差距',
#  '但美国仍对中国军力表示担心',
#  '美国专家将中国军力比作冰山',
#  '能看到的只是冰山一角',
#  '而大部分都隐藏在水下',
#  '美国《外交政策》杂志上月曾发表关于中国军力的文章',
#  '指出五角大楼对中国国防战略有5个最重要的问题未回答',
#  '包括中国的长期国防开支计划',
#  '核战略',
#  '海军目标等',
#  '因此',
#  '谈到华盛顿对中国的恐惧',
#  '可以做出这样的总结:美国担心中国是因为并不了解中国构成何种威胁',
#  '而对敌人不了解是最可怕的',
#  '日本《外交学者》6月1日文章',
#  '原题:中国军力报告的12点失误近年来',
#  '五角大楼年度中国军力报告一直是了解中国军力的权威信息来源',
#  '不过',
#  '2012年中国军力报告却有12个关键缺陷和遗漏',
#  '1.鉴于中国军力对美国利益的影响',
#  '美国纳税人应获得最高质量的中国军力发展信息',
#  '回避对中国军力发展重要方面的关键分析',
#  '对驻亚美军极为不利',
#  '2.什么因素会阻碍或促进今后数年中国军力发展?长远而言',
#  '不少因素会限制解放军的预算增长',
#  '如医疗和养老成本的提高',
#  '工资水平的上升',
#  '3.对中国国防工业发展关注太少',
#  '中国的国防工业正努力从“研究与仿造”跨越到真正的“研究与开发”',
#  '因此',
#  '报告作者最好能预估可能的结果',
#  '4.报告淡化中国军力可能导致中国认为美国言行不一',
#  '从而可能加以利用',
#  '如果奥巴马政府想通过淡化报告安抚北京',
#  '那么它应该考虑到这不仅不会建立信任',
#  '反而可能被中方认为软弱',
#  '5.报告对去年中国具有战略意义的武器着墨甚少',
#  '6.报告没有对中国的导弹提供任何重要的最新信息',
#  '环球网报道:日本《读卖新闻》6月6日消息称',
#  '据日本海上保安厅巡逻船确认',
#  '中国渔政船“渔政35001”6日上午8点25分(北京时间)左右在钓鱼岛黄尾屿西北约37公里处海域航行',
#  '报道称',
#  '中国渔政船航行区域位于钓鱼岛“毗邻区”',
#  '日海保巡逻船通过无线询问了中方船只的航行目的',
#  '并向渔政船发出“警告”称“不要进入日本领海”',
#  '中国渔政船则回应表示“中国渔政正在进行巡航”',
#  '大约1小时15分钟后',
#  '中国渔政船航行至钓鱼岛西北偏北44公里处海域',
#  '并驶离“毗邻水域”',
#  '据日本海保厅称',
#  '进入2012年以来',
#  '中方渔政船曾4次进入钓鱼岛“毗邻水域”',
#  '此次是第5次',
#  '日本《产经新闻》则报道称',
#  '此次是中国渔政船2012年第5次进入钓鱼岛“毗邻水域”',
#  '也是自东京都政府宣布“购买”钓鱼岛计划后的第2次',
#  '“很可能是一种挑衅行为”',
#  '[提要]党的纯洁性是同一切腐败现象对立的',
#  '坚决惩治各种腐败现象',
#  '是保持党的纯洁性的必然要求',
#  '历史和现实都表明',
#  '腐败是腐蚀军队纯洁肌肤的最大毒素',
#  '是影响部队凝聚力向心力战斗力的最大因素',
#  '保持军队党组织和干部队伍纯洁性',
#  '就要时刻牢记党面临的“四个考验”',
#  '“四个危险”',
#  '以更有力的措施突出抓好高中级干部的教育管理和监督',
#  '不断增强高中级干部的党性观念',
#  '道德修养和自律意识',
#  '使其在任何情况下都能稳得住心神',
#  '管得住行为',
#  '守得住清白',
#  '资料图:徐才厚在全军纪律检查工作会议上强调',
#  '以更大的决心',
#  '更有力的举措',
#  '更务实的作风',
#  '高标准抓好军队党风廉政建设和反腐败工作',
#  '中广军事记者韩瑞斌摄一个政党或组织的纯洁性',
#  '决定着这个政党或组织的先进性',
#  '在军队建设的内外环境发生深刻变化的今天',
#  '胡主席从党的建设的战略全局高度',
#  '从贯彻国防和军队建设主题主线',
#  '不断增强履行新世纪新阶段我军历史使命能力的实际要求出发',
#  '强调指出:“要加强军队反腐倡廉建设',
#  '保持军队党组织和干部队伍的纯洁性',
#  '”这一重要指示',
#  '是新时期加强军队党的建设的基本遵循',
#  '也是当前在党员领导干部中进行的“讲政治',
#  '顾大局',
#  '守纪律”教育活动的根本目标',
#  '时代在发展变化',
#  '保持军队党组织和干部队伍纯洁性更加显得重要我军历来重视保持党组织和干部队伍的纯洁性',
#  '在革命',
#  '建设和改革的各个历史时期',
#  '都对如何保持党组织和干部队伍的纯洁性进行过理论和实践探索',
#  '在人民军队初创时期',
#  '针对人员成分异常复杂',
#  '思想非常混乱的局面',
#  '毛泽东进行三湾改编',
#  '改变了过去国民革命军官兵人人皆为国民党员的做法',
#  '强调要吸收先进分子加入共产党',
#  '并在其后的古田会议上以决议的形式规定了入党的五个条件',
#  '极大地提升了军队党的纯洁性',
#  '党的十一届三中全会以后',
#  '中国进入改革开放和现代化建设的新阶段',
#  '人民军队也进入了快速发展的快车道',
#  '为了进一步维护军队党组织和干部队伍的纯洁性',
#  '中央军委颁发了《监察工作规定》《纪律条令》《政治工作条例》《党委工作条例》《党支部工作条例》《纪检工作条例》等政策法规',
#  '并在全军开展了“整党”“讲学习讲政治讲正气”“创先争优”等学习教育活动',
#  '正是源于此',
#  '人民军队才能在市场经济的冲洗下保持本色不变',
#  '才能在世界军事变革大潮中紧跟形势不落伍',
#  '俄罗斯《独立军事评论》消息',
#  '2011年国防订货的失败(最后一批合同直到11月份才签订)带来必然的组织结论并要求更认真地对待装备采购',
#  '但今年俄国防部在4月15日之前也仅顺利地安排了77%的国防订货',
#  '在此背景下',
#  '俄罗斯国防部向俄罗斯直升机控股公司购买直升机的形势显得一片大好',
#  '俄国防部已经签订了根据整个2020年前国家装备计划供应直升机的合同',
#  '甚至超额完成计划',
#  '在2020年前国家装备计划框架内',
#  '俄国防部将一共购买1120架作战和教练直升机',
#  '实际上计划购买1124架',
#  '俄罗斯国防部第一副部长亚历山大b苏霍鲁尼科夫肯定地说',
#  '所有生产合同已经签订',
#  '不仅如此',
#  '2011年11月国防部已经建议俄罗斯直升机控股公司增加直升机供应数量',
#  '苏霍鲁尼科夫说:在现有订货的情况下',
#  '企业每年能多生产9架直升机',
#  '”对近二十年来的军事冲突的分析表明',
#  '直升机在其中发挥了重要的作用',
#  '旋翼机执行侦察',
#  '火力支援',
#  '空降',
#  '运送伤员',
#  '向无设备场地运输急需物资',
#  '护送汽车车队',
#  '巡逻',
#  '搜索救援等任务',
#  '直升机已成为陆军',
#  '海军和护法力量的“老黄牛”',
#  '而且是可靠',
#  '勤劳',
#  '夜以继日工作的“老黄牛”',
#  '一年前',
#  '即2011年5月',
#  '俄官方首次公布了总统德米特里b梅德韦杰夫批准的2011-2010年国家装备计划框架内的2011-2018年技术装备供应合同',
#  '但详情没有公布',
#  '不过据悉一共签订了3份长期合同',
#  '同年8月',
#  '俄罗斯直升机控股公司总经理德米特里b彼得罗夫在2011年莫斯科国际航展开幕时说:“在2011年国防订货和2020年前国家装备计划框架内',
#  '我们签订了7份长期合同',
#  '3份短期合同',
#  '还有一份合同正在准备之中',
#  '我们将在8月底之前签订',
#  '这是超过450架直升机',
#  '还将签订一定数量的卡-52直升机合同',
#  '”这里所说的卡-52直升机将搭乘从法国购买的“西北风”级直升机母舰',
#  '同时',
#  '当时俄罗斯国防部的专家刚刚确定了“西北风”级舰的数量',
#  '初步估计到2020年前卡-52的供应数量将超过100架',
#  '在生产卡-52K的同时还将生产一定数量的卡-29武装运输直升机',
#  '2011年8月31日签订了总额超过1200亿卢布的合同',
#  '第一批试验型卡-52K舰载直升机应在2012年生产出来',
#  '而2014年在位于滨海边疆区的阿尔谢尼耶夫工厂开始批量生产',
#  '国防工业公司总经理安德列b雷乌斯指出',
#  '已经为企业改造投资超过30亿卢布',
#  '近期计划再投资不少于60亿卢布',
#  '有消息说',
#  '与基本型相比',
#  '卡-52K将采用一系列新技术',
#  '包括',
#  '该机将装备桨叶和悬臂折叠装置和强化起落架',
#  '后者能使直升机在战舰剧烈摇摆的时候也能在甲板上降落',
#  '不排除在卡-52K上将安装新型航电设备和雷达系统',
#  '考虑到海洋工作环境',
#  '还可能会更换武器',
#  '为设计和科研工作拨出了不少经费',
#  '为米-38',
#  '卡-62',
#  '米34S1直升机的研发和米-17直升机的改进拨款约2.5亿美元',
#  '2012年1月',
#  '米里直升机厂已经开始组装米-171A2直升机的第一架原型机',
#  '其机身来自乌兰乌德航空制造厂',
#  '计划2014年开始批量生产',
#  '在此之前原型机将进行全周期的飞行试验',
#  '并将取得俄罗斯和国外的飞行标准认证',
#  '米-171A2是以米-171A1为原型研制的',
#  '据俄罗斯直升机控股公司称',
#  '该机的飞行安全水平是米-8/米-17系列直升机中最高的',
#  '其特点是维护和每飞行小时成本更低',
#  '此外',
#  '它能在零下50到零上50摄氏度的环境中飞行',
#  '悬停时可承受的侧风速度更大',
#  '制式油箱能使它吊挂5吨货物飞行850公里',
#  '这只是米-171A2直升机技术性能的一部分',
#  '其他能力暂时尚未公布',
#  '俄罗斯空军正在快速换装新技术装备',
#  '位于克拉斯诺达尔边疆区的空军和防空军团的航空基地(布琼诺夫斯克航空基地',
#  '斯塔夫罗波尔边疆区)到2012年底之前将全面装备米-28N和米-8АМТШ新型直升机',
#  '此外',
#  '已经老化的米-24直升机将被米-35M所取代',
#  '南方军区陆军航空兵年内将接收卡-52“短吻鳄”武装直升机和米-26T多用途运输直升机',
#  '俄罗斯直升机控股公司与俄罗斯国防部之间已经形成了可靠的伙伴关系',
#  '大部分企业的生产为两班倒',
#  '以在合同期限内高质量地完成任务',
#  '国防部则理顺了货款无延迟支付过程',
#  '航空制造者根据国防工业综合体发展计划获得经费并将其用于资产更新',
#  '因此毫不奇怪',
#  '俄国防部可以修改计划',
#  '灵活地增加新技术装备采购数量',
#  '包括',
#  '签订了补充采购27架米-35直升机的合同',
#  '考虑到企业的能力',
#  '近期可能会签订增加采购米-28和米-8МТШ直升机的类似合同',
#  '据媒体报道',
#  '俄罗斯国防部2012年应接收124架各型直升机',
#  '但不排除最终接收数量会超过这一数字',
#  '俄罗斯直升机制造部门联合为一个控股公司有利于生产:2000年代初',
#  '俄罗斯直升机在世界市场上只占3%的份额',
#  '而2011年这一指标已经相当惊人——14%',
#  '而未来增长潜力还很大',
#  '知远/蓝山',
#  '资料图:5月23日',
#  '在北京国家会议中心举办的“第六届中国国际警用装备博览会”热闹非凡',
#  '中国兵器装备集团下属部门生产的CS/LM12型7.62毫米转管机枪最高射频为每分钟6000发',
#  '常用射频每分钟2500发',
#  '以小于或等于2.3千瓦的电力',
#  '驱动枪管转轮旋转',
#  '中新社发邹宪摄东方网消息:据美国战略之页网站2012年6月1日报道',
#  '中国重庆建设工业集团制造的CS/LM12六管7.62毫米机枪正在装备中国陆军和警察部队',
#  '美军50年前首次装备这种多管机枪',
#  '安装在喷气式战斗机上',
#  '发射20毫米口径的子弹',
#  '这种机枪也被称为“加特林机枪”',
#  '这种基本设计很快被用于发射7.62毫米子弹',
#  '可供直升机或地面车辆安装',
#  '这种武器的最新版本是美国空军的GAU-2B',
#  '这是一种远程控制的使用六管7.62毫米机枪的炮塔',
#  '该系统的射速为每分钟3000发(每秒50发)',
#  '最大射程1500米',
#  '该系统的重量为363公斤(800磅)',
#  '包括4000发子弹',
#  '机组成员可以使用视频游戏一样的操作界面来操作枪',
#  '最初GAU-2(美国陆军将其称为M134)的设计射速是每分钟6000发',
#  '但后来发现',
#  '每分钟4000发子弹的射速足够了',
#  '而且可以更有效地使用弹药',
#  '中国在20世纪90年代也开始制造类似的武器',
#  '现在部分精锐步兵部队装备了这种7.62毫米武器',
#  '中国的CS/LM12射速(2500至6000发/分钟)可以调节',
#  '中国在中东影响力仍有限5月31日',
#  '日本《外交家》杂志刊发《中国夹在了以色列和伊朗中间》一文',
#  '文章称',
#  '近期有消息传出',
#  '以色列和伊朗两国元首将几乎同时访华',
#  '与中国探讨伊朗核问题',
#  '当前正值伊朗局势备受关注之时',
#  '这一现象颇为有趣',
#  '中国不经意间夹在了两个冤家之间',
#  '成为双方极力拉拢的宠儿',
#  '中东冤家争抢中国文章称',
#  '中国在外交上被夹在了伊朗和以色列之间',
#  '成为双方争相讨好拉拢的宠儿',
#  '这一现象突显出中国在国际舞台上正发挥出日益重要的作用',
#  '同时也说明能源在国际关系中正扮演越来越重要的角色',
#  '日前有消息传出',
#  ...]

# %%
WORD_NUM, words_freq, candidate_words_freq, candidate_words_left_characters, candidate_words_right_characters = \
get_candidate_wordsinfo(texts = texts, max_word_len = 6)  # 字符串最长为 3
# Out:
# 100%|██████████| 189298/189298 [00:45<00:00, 4158.51it/s]

# %%
# texts = texts[:3]
# WORD_NUM, words_freq, candidate_words_freq, candidate_words_left_characters, candidate_words_right_characters = get_candidate_wordsinfo(texts = texts, max_word_len = 6)

# %% [markdown]
# ### 根据第二步中统计的进行 pmi 值以及左右邻字熵的计算

# %%
import math

# 计算候选单词的 pmi 值
def compute_pmi(words_freq, candidate_words_freq):
    words_pmi = {}
    with tqdm(candidate_words_freq, total=len(candidate_words_freq), desc="Counting pmi") as pbar:
        for word in pbar:
            # 首先，将某个候选单词按照不同的切分位置切分成两项，比如“电影院”可切分为“电”和“影院”以及“电影”和“院”
            bi_grams = [(word[0:i],word[i:]) for i in range(1,len(word))]
            # 对所有切分情况计算 pmi 值，取最大值作为当前候选词的最终 pmi 值
            # words_freq[bi_gram[0]]，words_freq[bi_gram[1]] 分别表示一个候选新词的前后两部分的出现频次
            words_pmi[word] = max(map(lambda bi_gram: math.log(\
                words_freq[word]/(words_freq[bi_gram[0]]*words_freq[bi_gram[1]]/WORD_NUM)), bi_grams))
    return words_pmi

# %% [markdown]
# 在下一步中，计算 pmi 值以及左右邻字熵。

# %%
words_pmi = compute_pmi(words_freq, candidate_words_freq)
words_pmi
# Out:
# Counting pmi: 100%|██████████| 5281978/5281978 [00:26<00:00, 199521.98it/s]
# {'南亚': 4.380790003231923,
#  '南亚地': 6.54769658610351,
#  '南亚地区': 7.875758676517223,
#  '南亚地区的': 8.09730973964447,
#  '南亚地区的权': 14.101196806751007,
#  '亚地': 2.8190789369950906,
#  '亚地区': 7.834936681996968,
#  '亚地区的': 8.867417961340543,
#  '亚地区的权': 12.38639837865908,
#  '亚地区的权威': 12.38639837865908,
#  '地区': 5.803329855561481,
#  '地区的': 6.592786213037017,
#  '地区的权': 7.079220383678848,
#  '地区的权威': 9.452541508823177,
#  '地区的权威军': 15.199809095419118,
#  '区的': 2.737928898083608,
#  '区的权': 3.7982212326115037,
#  '区的权威': 9.452541508823177,
#  '区的权威军': 15.199809095419118,
#  '区的权威军事': 16.298421384087227,
#  '的权': 1.9878739023503313,
#  '的权威': 7.939953422378995,
#  '的权威军': 11.122271651513397,
#  '的权威军事': 12.220883940181508,
#  '的权威军事来': 14.218979842407391,
#  '权威': 5.895052882834653,
#  '权威军': 7.953441015316657,
#  '权威军事': 9.052053303984767,
#  '权威军事来': 14.218979842407391,
#  '权威军事来源': 16.298421384087227,
#  '威军': 0.7115116730039129,
#  '威军事': 6.450076631048308,
#  '威军事来': 13.120367553739282,
#  '威军事来源': 15.199809095419118,
#  '威军事来源称': 15.199809095419118,
#  '军事': 5.598880546623339,
#  '军事来': 4.379337717920017,
#  '军事来源': 8.91691948958052,
#  '军事来源称': 15.199809095419118,
#  '事来': 0.5590080913356087,
#  '事来源': 6.837477947900684,
#  '事来源称': 13.120367553739282,
#  '来源': 6.582388779492823,
#  '来源称': 7.229299014026582,
#  '源称': 2.2999622437284217,
#  '巴基': 6.203607854535211,
#  '巴基斯': 9.05653641021113,
#  '巴基斯坦': 10.004599031225577,
#  '巴基斯坦陆': 10.294534316980688,
#  '巴基斯坦陆军': 9.958062080359475,
#  '基斯': 5.146336906023543,
#  '基斯坦': 9.299464616301503,
#  '基斯坦陆': 10.290427535028035,
#  '基斯坦陆军': 9.953955298406822,
#  '基斯坦陆军进': 10.805359940746678,
#  '斯坦': 7.298237828728043,
#  '斯坦陆': 8.003372243652116,
#  '斯坦陆军': 8.003372243652116,
#  '斯坦陆军进': 10.124635280185291,
#  '斯坦陆军进口': 13.995836291093182,
#  '坦陆': 4.183782790261378,
#  '坦陆军': 6.10210431566112,
#  '坦陆军进': 10.124635280185291,
#  '坦陆军进口': 13.995836291093182,
#  '坦陆军进口了': 13.995836291093182,
#  '陆军': 5.156702977563979,
#  '陆军进': 5.004846672192513,
#  '陆军进口': 8.91133114843047,
#  '陆军进口了': 13.465208040031012,
#  '陆军进口了中': 16.298421384087227,
#  '军进': 1.2991254805063075,
#  '军进口': 5.0401301375225795,
#  '军进口了': 9.59400702912312,
#  '军进口了中': 12.427220373179336,
#  '军进口了中国': 12.427220373179336,
#  '进口': 3.850768271981156,
#  '进口了': 6.043791162463675,
#  '进口了中': 7.267566594085791,
#  '进口了中国': 7.271883665186797,
#  '进口了中国生': 13.659364054471968,
#  '口了': 1.9700842056867955,
#  '口了中': 3.6179205371830823,
#  '口了中国': 6.222115622188955,
#  '口了中国生': 13.659364054471968,
#  '口了中国生产': 13.813514734299227,
#  '了中': 2.070301140791769,
#  '了中国': 5.884733881184901,
#  '了中国生': 8.265736508119607,
#  '了中国生产': 8.848923378704377,
#  '了中国生产的': 11.62559254962532,
#  '中国': 5.148831719541957,
#  '中国生': 5.4215144640581405,
#  '中国生产': 8.625779827390168,
#  '中国生产的': 11.11476692585933,
#  '中国生产的C': 13.995836291093182,
#  '国生': 0.23602261888288367,
#  '国生产': 8.69477269887712,
#  '国生产的': 11.289120313004108,
#  '国生产的C': 12.966216873912023,
#  '国生产的CH': 13.659364054471968,
#  '生产': 6.54813200816436,
#  '生产的': 7.407161463968245,
#  '生产的C': 7.673271051165898,
#  '生产的CH': 10.044592572511755,
#  '生产的CH-': 11.342594326485967,
#  '产的': 2.38003536762613,
#  '产的C': 5.958551620808214,
#  '产的CH': 10.044592572511755,
#  '产的CH-': 11.342594326485967,
#  '产的CH-3': 15.605274203527282,
#  '的C': 2.1920043742408106,
#  '的CH': 8.252833103283699,
#  '的CH-': 9.550834857257911,
#  '的CH-3': 12.714902445631118,
#  '的CH-3A': 13.813514734299227,
#  'CH': 6.962109372549109,
#  'CH-': 7.279281873511595,
#  'CH-3': 9.750202281324855,
#  'CH-3A型': 14.506661914859173,
#  'H-': 6.947486593315447,
#  'H-3': 4.53723057902901,
#  'H-3A': 9.956299965366076,
#  'H-3A型': 13.079545559219026,
#  'H-3A型攻': 16.298421384087227,
#  '-3': 5.791828874889035,
#  '-3A': 7.552341166729715,
#  '-3A型': 8.24548834728966,
#  '-3A型攻': 12.714902445631118,
#  '-3A型攻击': 12.714902445631118,
#  '3A': 2.6154501395922076,
#  '3A型': 6.236563495579658,
#  '3A型攻': 12.021755265071173,
#  '3A型攻击': 12.021755265071173,
#  '3A型攻击无': 15.605274203527282,
#  'A型': 4.426636722396154,
#  'A型攻': 6.992952667019467,
#  'A型攻击': 8.32733563058162,
#  'A型攻击无': 15.199809095419118,
#  'A型攻击无人': 15.605274203527282,
#  '型攻': 3.4691967173210285,
#  '型攻击': 8.32733563058162,
#  '型攻击无': 13.002584518082898,
#  '型攻击无人': 13.408049626191064,
#  '型攻击无人机': 13.408049626191064,
#  '攻击': 7.775542568327407,
#  '攻击无': 8.848923378704377,
#  '攻击无人': 9.254388486812543,
#  '攻击无人机': 9.908180717021878,
#  '击无': 1.3858232548013498,
#  '击无人': 6.220392462076107,
#  '击无人机': 9.502715608913713,
#  '无人': 5.27781664824252,
#  '无人机': 8.227629921245875,
#  '人机': 3.819755374917292,
#  '但是': 4.959504816215283,
#  '但是截': 7.725226002555705,
#  '但是截至': 8.90392827686819,
#  '但是截至2': 11.321687641666653,
#  '但是截至20': 11.879580776290629,
#  '是截': 1.2798775630276835,
#  '是截至': 8.210781096308244,
#  '是截至2': 10.628540461106708,
#  '是截至20': 11.186433595730684,
#  '是截至201': 11.916394749413346,
#  '截至': 7.13725564206987,
#  '截至2': 8.084163257720379,
#  '截至20': 7.754753197343453,
#  '截至201': 8.148242114404901,
#  '截至2012': 8.841389294964847,
#  '至2': 4.4855863392946915,
#  '至20': 6.0295944242873265,
#  '至201': 7.4278286068661785,
#  '至2012': 7.3327035951023785,
#  '至2012年': 8.69419113445247,
#  '20': 5.6528230562344834,
#  '201': 6.829942481195335,
#  '2012': 6.999347405019651,
#  '2012年': 8.382790100068384,
#  '01': 4.64785251253392,
#  '012': 5.7944979115310185,
#  '012年': 8.309386877170564,
#  '12': 4.693525666903958,
#  '12年': 6.399237996447645,
#  '2年': 4.143188586195519,
#  '只进': 1.9467269901889328,
#  '只进口': 6.714106571094251,
#  '只进口了': 11.267983462694792,
#  '只进口了飞': 14.101196806751007,
#  '只进口了飞机': 14.101196806751007,
#  '进口了飞': 8.233784908313005,
#  '进口了飞机': 10.02554437754106,
#  '进口了飞机本': 15.605274203527282,
#  '口了飞': 4.866066265967606,
#  '口了飞机': 7.1020785217548985,
#  '口了飞机本': 15.605274203527282,
#  '口了飞机本身': 15.605274203527282,
#  '了飞': 2.0191638854460323,
#  '了飞机': 5.310319052526843,
#  '了飞机本': 11.51092964130518,
#  '了飞机本身': 11.51092964130518,
#  '飞机': 5.4479878114173275,
#  '飞机本': 7.699279610023822,
#  '飞机本身': 8.683616019376153,
#  '机本': -0.6506862870964302,
#  '机本身': 8.683616019376153,
#  '本身': 4.528163471113271,
#  '没有': 6.485925381783513,
#  '没有进': 7.835895594013298,
#  '没有进口': 8.529042774573243,
#  '没有进口A': 12.56075176580386,
#  '没有进口AR': 12.966216873912023,
#  '有进': 1.1165070308085767,
#  '有进口': 5.579126638255267,
#  '有进口A': 11.867604585243914,
#  '有进口AR': 12.273069693352078,
#  '有进口AR—': 15.199809095419118,
#  '进口A': 6.862101485977627,
#  '进口AR': 10.274973791126195,
#  '进口AR—': 15.199809095419118,
#  '进口AR—1': 15.199809095419118,
#  '口A': 2.9016992973670392,
#  '口AR': 9.86950868301803,
#  '口AR—': 14.794343987310953,
#  '口AR—1': 14.794343987310953,
#  '口AR—1反': 15.199809095419118,
#  'AR': 7.688518228443694,
#  'AR—': 9.190177244355686,
#  'AR—1反': 14.912127022967336,
#  'AR—1反坦': 15.199809095419118,
#  'R—': 3.809347604623813,
#  'R—1': 7.4032941662421825,
#  'R—1反': 14.912127022967336,
#  'R—1反坦': 15.199809095419118,
#  'R—1反坦克': 15.199809095419118,
#  '—1': 3.1821012871770638,
#  '—1反': 8.446500836464956,
#  '—1反坦': 9.73786230508928,
#  '—1反坦克': 10.26293995156247,
#  '—1反坦克导': 13.207378930728911,
#  '1反': 0.3471351477262356,
#  '1反坦': 9.015889325802375,
#  '1反坦克': 9.975257879110691,
#  '1反坦克导': 13.207378930728911,
#  '1反坦克导弹': 13.207378930728911,
#  '反坦': 5.177243790179005,
#  '反坦克': 8.54265421398423,
#  '反坦克导': 12.609541929973291,
#  '反坦克导弹': 12.609541929973291,
#  '坦克': 7.583285660675915,
#  '坦克导': 9.303571398254157,
#  '坦克导弹': 9.303571398254157,
#  '克导': 3.1318201800382015,
#  '克导弹': 8.173382286719482,
#  '导弹': 7.181936355793145,
#  '基斯坦陆军消': 13.120367553739282,
#  '斯坦陆军消': 12.609541929973291,
#  '斯坦陆军消息': 13.302689110533237,
#  '坦陆军消': 12.609541929973291,
#  '坦陆军消息': 13.302689110533237,
#  '坦陆军消息来': 13.995836291093182,
#  '陆军消': 7.489753321980513,
#  '陆军消息': 8.426728719763583,
#  '陆军消息来': 13.813514734299227,
#  '陆军消息来源': 13.995836291093182,
#  '军消': 0.8837775748095765,
#  '军消息': 7.7335815392036364,
#  '军消息来': 12.427220373179336,
#  '军消息来源': 12.609541929973291,
#  '军消息来源对': 16.298421384087227,
#  '消息': 7.862362329069562,
#  '消息来': 9.04944326572528,
#  '消息来源': 9.113981786862851,
#  '消息来源对': 14.101196806751007,
#  '消息来源对加': 14.101196806751007,
#  '息来': 1.8425129994909375,
#  '息来源': 8.734597932786565,
#  '息来源对': 13.813514734299227,
#  '息来源对加': 13.813514734299227,
#  '息来源对加拿': 13.813514734299227,
#  '来源对': 7.229299014026582,
#  '来源对加': 7.862655191366719,
#  '来源对加拿': 11.438608979725554,
#  '来源对加拿大': 11.438608979725554,
#  '源对': -0.3252102048850697,
#  '源对加': 7.862655191366719,
#  '源对加拿': 11.438608979725554,
#  '源对加拿大': 11.438608979725554,
#  '源对加拿大《': 13.900526111288857,
#  '对加': 0.9231105898951748,
#  '对加拿': 9.33617791982102,
#  '对加拿大': 10.7377397530717,
#  '对加拿大《': 12.204076821865126,
#  '对加拿大《汉': 12.491758894316908,
#  '加拿': 6.45337131202213,
#  '加拿大': 7.854933145272809,
#  '加拿大《': 11.351597602735925,
#  '加拿大《汉': 11.438608979725556,
#  '加拿大《汉和': 13.26453734456886,
#  '拿大': 5.504531010967649,
#  '拿大《': 9.942313723391337,
#  '拿大《汉': 10.920061309865654,
#  '拿大《汉和': 13.26453734456886,
#  '拿大《汉和防': 13.699855415826706,
#  '大《': 1.5219801175073047,
#  '大《汉': 10.513571086342244,
#  '大《汉和': 13.17752596757923,
#  '大《汉和防': 13.612844038837077,
#  '大《汉和防务': 13.73347202662569,
#  '《汉': 5.640283983397212,
#  '《汉和': 8.235245993147247,
#  '《汉和防': 11.74982154958753,
#  '《汉和防务': 13.328006918517525,
#  '《汉和防务评': 13.495061003180693,
#  '汉和': 4.0628219185516645,
#  '汉和防': 9.056013705200863,
#  '汉和防务': 10.634199074130859,
#  '汉和防务评': 13.465208040031012,
#  '和防': 2.3700679730990584,
#  '和防务': 6.229592158974531,
#  '和防务评': 11.719968586437849,
#  '和防务评论': 11.914124600878807,
#  '和防务评论》': 13.20284377556352,
#  '防务': 5.185669756603041,
#  '防务评': 7.798577831006103,
#  '防务评论': 8.514423857463612,
#  '防务评论》': 12.818580875105958,
#  '防务评论》称': 13.465208040031012,
#  '务评': 3.41042771855145,
#  '务评论': 8.514423857463612,
#  '务评论》': 12.818580875105958,
#  '务评论》称': 13.465208040031012,
#  '评论': 6.71976373355492,
#  '评论》': 8.856549137010727,
#  '评论》称': 9.067858230677935,
#  '论》': 3.8844654154438256,
#  '论》称': 6.231476592403541,
#  '》称': 4.646040588107177,
#  '目前': 6.354801698118702,
#  '目前正': 7.8135009774640105,
#  '目前正在': 7.900512354453641,
#  '目前正在对': 8.313277452888608,
#  '目前正在对C': 11.415619461500857,
#  '前正': 3.9958988675384637,
#  '前正在': 5.851261612380163,
#  '前正在对': 8.120905560241152,
#  '前正在对C': 11.2232475688534,
#  '前正在对CH': 12.8326854812875,
#  '正在': 4.972824603887391,
#  '正在对': 6.551677084880893,
#  '正在对C': 7.946102835861224,
#  '正在对CH': 10.7377397530717,
#  '正在对CH—': 14.506661914859173,
#  '在对': 1.567771916892448,
#  '在对C': 5.9547130921526605,
#  '在对CH': 10.7377397530717,
#  '在对CH—': 14.506661914859173,
#  '在对CH—3': 14.912127022967336,
#  '对C': 2.117510499293365,
#  '对CH': 9.821449021197544,
#  '对CH—': 13.590371182985017,
#  '对CH—3': 13.995836291093182,
#  '对CH—3进': 15.605274203527282,
#  'CH—': 9.344737173216691,
#  'CH—3进': 14.912127022967336,
#  'CH—3进行': 14.912127022967336,
#  'H—': 4.965260747129264,
#  'H—3': 8.362833998498028,
#  'H—3进': 14.506661914859173,
#  'H—3进行': 14.506661914859173,
#  'H—3进行测': 14.506661914859173,
#  '—3': 3.841214378166984,
#  '—3进': 8.734182908916736,
#  '—3进行': 8.734182908916736,
#  '—3进行测': 13.040324846065745,
#  '—3进行测试': 13.253898946363805,
#  '3进': -0.6934548717975787,
#  '3进行': 6.981021939817637,
#  '3进行测': 13.040324846065745,
#  '3进行测试': 13.253898946363805,
#  '进行': 6.041488423346611,
#  '进行测': 6.899841813960474,
#  '进行测试': 8.34691622558022,
#  '行测': 2.93325844515511,
#  '行测试': 8.458764525716788,
#  '测试': 7.260881427595689,
#  '一旦': 5.9447995609947,
#  '一旦效': 6.185564713658729,
#  '一旦效果': 8.773860157801867,
#  '一旦效果理': 16.298421384087227,
#  '一旦效果理想': 16.298421384087227,
#  '旦效': 3.6105215340764696,
#  '旦效果': 8.773860157801867,
#  '旦效果理': 16.298421384087227,
#  '旦效果理想': 16.298421384087227,
#  '效果': 6.899579664885809,
#  '效果理': 9.04424353763071,
#  '效果理想': 9.04424353763071,
#  '果理': 0.41051769120389037,
#  '果理想': 8.575743867619224,
#  '理想': 5.024585756393664,
#  '就会': 4.071376471870763,
#  '就会考': 5.266180385971003,
#  '就会考虑': 10.36352718846764,
#  '就会考虑进': 14.912127022967336,
#  '就会考虑进口': 16.298421384087227,
#  '会考': 2.496057617717873,
#  '会考虑': 10.07584511601586,
#  '会考虑进': 12.427220373179336,
#  '会考虑进口': 13.813514734299227,
#  '会考虑进口A': 15.199809095419118,
#  '考虑': 8.688073805582228,
#  '考虑进': 8.932608546877756,
#  '考虑进口': 8.932608546877756,
#  '考虑进口A': 13.813514734299227,
#  '考虑进口AR': 14.218979842407391,
#  '虑进': 2.718966759586094,
#  '虑进口': 7.52503678731058,
#  '虑进口A': 13.813514734299227,
#  '虑进口AR': 14.218979842407391,
#  '虑进口AR—': 15.199809095419118,
#  '报道': 6.768354033474704,
#  '报道称': 7.511353738869174,
#  '道称': 5.532792770783583,
#  '巴基斯坦非': 10.805359940746678,
#  '巴基斯坦非常': 10.805359940746678,
#  '基斯坦非': 10.801253158794026,
#  '基斯坦非常': 10.801253158794026,
#  '基斯坦非常重': 12.309437337522953,
#  '斯坦非': 8.003372243652116,
#  '斯坦非常': 8.508966818000554,
#  '斯坦非常重': 12.309437337522953,
#  '斯坦非常重视': 14.352511235031914,
#  '坦非': 2.0557788164863102,
#  '坦非常': 8.508966818000554,
#  '坦非常重': 12.309437337522953,
#  '坦非常重视': 14.352511235031914,
#  '坦非常重视C': 16.298421384087227,
#  '非常': 7.619016502740807,
#  '非常重': 9.031936669307228,
#  '非常重视': 9.05062880231938,
#  '非常重视C': 12.328129470535105,
#  '非常重视CH': 12.328129470535105,
#  '常重': 4.050536567756508,
#  '常重视': 6.887007800266885,
#  '常重视C': 12.309437337522953,
#  '常重视CH': 12.309437337522953,
#  '常重视CH—': 14.506661914859173,
#  '重视': 5.805677380105934,
#  '重视C': 7.851007087278907,
#  '重视CH': 10.7377397530717,
#  '重视CH—': 14.506661914859173,
#  '重视CH—3': 14.912127022967336,
#  '视C': 2.381862595013474,
#  '视CH': 10.7377397530717,
#  '视CH—': 14.506661914859173,
#  '视CH—3': 14.912127022967336,
#  '目前还': 7.517520102197535,
#  '目前还在': 8.005872870111467,
#  '目前还在考': 9.911542064724582,
#  '目前还在考虑': 10.517677868294898,
#  '前还': 3.311586457035476,
#  '前还在': 4.186213089076453,
#  '前还在考': 9.42318929681065,
#  '前还在考虑': 10.36352718846764,
#  '前还在考虑是': 14.912127022967336,
#  '还在': 3.04874333678655,
#  '还在考': 6.128194536119244,
#  '还在考虑': 9.958062080359475,
#  '还在考虑是': 13.813514734299227,
#  '还在考虑是否': 14.506661914859173,
#  '在考': 2.0464948577747424,
#  '在考虑': 9.757391384897325,
#  '在考虑是': 12.514231750168966,
#  '在考虑是否': 12.514231750168966,
#  '在考虑是否由': 15.605274203527282,
#  '考虑是': 8.644926474425974,
#  '考虑是否': 9.641052392813174,
#  '考虑是否由': 15.199809095419118,
#  '考虑是否由巴': 15.199809095419118,
#  '虑是': 2.108868275970531,
#  '虑是否': 9.353370320361392,
#  '虑是否由': 14.912127022967336,
#  '虑是否由巴': 14.912127022967336,
#  '虑是否由巴基': 14.912127022967336,
#  '是否': 6.01869233369241,
#  '是否由': 6.657468110470228,
#  '是否由巴': 9.060643192163784,
#  '是否由巴基': 10.801253158794026,
#  '是否由巴基斯': 10.805359940746678,
#  '否由': 2.324725724103803,
#  '否由巴': 9.060643192163784,
#  '否由巴基': 10.801253158794026,
#  '否由巴基斯': 10.805359940746678,
#  '否由巴基斯坦': 10.805359940746678,
#  '由巴': 3.130610884574304,
#  '由巴基': 6.845605532497343,
#  '由巴基斯': 9.702640870125915,
#  '由巴基斯坦': 10.00870581317823,
#  '由巴基斯坦自': 14.912127022967336,
#  '巴基斯坦自': 10.112212760186733,
#  '巴基斯坦自己': 10.805359940746678,
#  '基斯坦自': 10.10810597823408,
#  '基斯坦自己': 10.801253158794026,
#  '基斯坦自己生': 15.199809095419118,
#  '斯坦自': 8.003372243652116,
#  '斯坦自己': 8.282103485583812,
#  '斯坦自己生': 14.506661914859173,
#  '斯坦自己生产': 14.912127022967336,
#  '坦自': 1.4521047918218721,
#  '坦自己': 8.282103485583812,
#  '坦自己生': 14.506661914859173,
#  '坦自己生产': 14.912127022967336,
#  '坦自己生产的': 15.605274203527282,
#  '自己': 7.7092658214722105,
#  '自己生': 7.753807597094998,
#  '自己生产': 8.443458270596214,
#  '自己生产的': 10.526980260957211,
#  '自己生产的可': 15.199809095419118,
#  '己生': 1.4487126218905377,
#  '己生产': 8.443458270596214,
#  '己生产的': 10.526980260957211,
#  '己生产的可': 15.199809095419118,
#  '己生产的可能': 15.199809095419118,
#  '生产的可': 7.673271051165898,
#  '生产的可能': 7.673271051165898,
#  '生产的可能性': 11.928973531620207,
#  '产的可': 3.6178147618497913,
#  '产的可能': 7.319508783012952,
#  '产的可能性': 11.928973531620207,
#  '的可': 1.9427606417631045,
#  '的可能': 6.507240773954963,
#  '的可能性': 10.723216605500768,
#  '可能': 5.958682691472313,
#  '可能性': 7.787986111185821,
#  '能性': 3.616177302310475,
#  '相关': 6.2858332060213575,
#  '相关的': 7.704154924386997,
#  '相关的构': 8.456142604969875,
#  '相关的构思': 10.029325100380966,
#  '相关的构思已': 16.298421384087227,
#  '关的': 1.6684560981429364,
#  '关的构': 5.383623871285786,
#  '关的构思': 9.277337419798087,
#  '关的构思已': 16.298421384087227,
#  '关的构思已经': 16.298421384087227,
#  '的构': 0.7872566860800514,
#  '的构思': 7.226653661974985,
#  '的构思已': 13.813514734299227,
#  '的构思已经': 13.813514734299227,
#  '的构思已经进': 13.813514734299227,
#  '构思': 4.243500170627853,
#  '构思已': 9.444066881832205,
#  '构思已经': 9.444066881832205,
#  '构思已经进': 12.660835224360842,
#  '构思已经进行': 14.101196806751007,
#  '思已': 1.0874877587196512,
#  '思已经': 7.902492280164029,
#  '思已经进': 12.660835224360842,
#  '思已经进行': 14.101196806751007,
#  '思已经进行了': 14.352511235031914,
#  '已经': 7.078992381791346,
#  '已经进': 8.340827764521677,
#  '已经进行': 8.367496011603839,
#  '已经进行了': 8.367496011603839,
#  '已经进行了较': 11.994356290883058,
#  '经进': 2.509223649888979,
#  '经进行': 5.540660357427471,
#  '经进行了': 8.006874874203318,
#  '经进行了较': 11.967688043800896,
#  '经进行了较长': 14.101196806751007,
#  '进行了': 7.032446851724866,
#  '进行了较': 7.267566594085791,
#  '进行了较长': 8.207100110556818,
#  '进行了较长时': 11.116637833795142,
#  '行了': 3.8064321522305824,
#  '行了较': 4.272971738715427,
#  '行了较长': 7.019861773133901,
#  '行了较长时': 11.116637833795142,
#  '行了较长时间': 11.2232475688534,
#  '了较': 3.251860511181838,
#  '了较长': 4.311811572031691,
#  '了较长时': 8.408587632692932,
#  '了较长时间': 8.96148447037961,
#  '较长': 4.258586810794393,
#  '较长时': 7.082397195642747,
#  '较长时间': 7.987760478180003,
#  '长时': 2.9694456170969095,
#  '长时间': 7.8811507431217445,
#  '时间': 6.092497685558544,
#  'CH—3的': 13.525832661847446,
#  'CH—3的最': 14.912127022967336,
#  'H—3的': 11.941712557397636,
#  'H—3的最': 14.506661914859173,
#  'H—3的最大': 14.506661914859173,
#  '—3的': 6.1692335514552,
#  '—3的最': 8.734182908916736,
#  '—3的最大': 10.046517500921338,
#  '—3的最大航': 14.101196806751007,
#  '3的': -0.9325147504347053,
#  '3的最': 5.594323347741625,
#  '3的最大': 7.481568143459802,
#  '3的最大航': 13.040324846065745,
#  '3的最大航程': 15.605274203527282,
#  '的最': 2.7827469624478525,
#  '的最大': 5.535350896105922,
#  '的最大航': 7.275133743280901,
#  '的最大航程': 9.840083100742437,
#  '的最大航程2': 13.353982404920787,
#  '最大': 5.018848048500151,
#  '最大航': 7.0984007445179,
#  '最大航程': 8.159272705203161,
#  '最大航程2': 11.156757827584567,
#  '最大航程24': 13.002584518082898,
#  '大航': 1.3332078712873119,
#  '大航程': 5.706975087680278,
#  '大航程2': 10.095885866899305,
#  '大航程24': 11.941712557397636,
#  '大航程240': 12.3471776655058,
#  '航程': 3.2021430498828796,
#  '航程2': 5.621613182636398,
#  '航程24': 7.539223633715862,
#  '航程240': 9.796381244468463,
#  '航程2400': 11.150926907273774,
#  '程2': 1.8212877443141826,
#  '程24': 6.098862051325695,
#  '程240': 7.6157985035472535,
#  '程2400': 8.562332651990078,
#  '程2400公': 11.744544492486686,
#  '24': 4.778124065421136,
#  '240': 3.906001826644822,
#  '2400': 5.232941896105992,
#  '2400公': 7.3076061179025436,
#  '2400公里': 8.055138861038852,
#  '40': 4.6650859985815805,
#  '400': 5.640953410468479,
#  '400公': 5.9197001528883115,
#  '400公里': 8.055138861038852,
#  '00': 5.3003149803590635,
#  '00公': 5.866941404163243,
#  '00公里': 7.891685788549281,
#  '0公': 4.007504756935305,
#  '0公里': 7.87358920702348,
#  '公里': 6.306889402908946,
#  '滞空': 4.403739657655642,
#  '滞空时': 10.00870581317823,
#  '滞空时间': 12.4066010859766,
#  '滞空时间1': 12.4066010859766,
#  '滞空时间12': 13.659364054471968,
#  '空时': 1.4612555222355623,
#  '空时间': 5.589865205381632,
#  '空时间1': 9.129841486823192,
#  '空时间12': 11.261468781673598,
#  '空时间12小': 13.408049626191064,
#  '时间1': 7.0662216777581515,
#  '时间12': 7.0662216777581515,
#  '时间12小': 9.225151666627516,
#  '时间12小时': 9.330512182285343,
#  '间1': 2.5429243867939277,
#  '间12': 4.771718409242749,
#  '间12小': 9.225151666627516,
#  '间12小时': 9.330512182285343,
#  '12小': 5.977540152577661,
#  '12小时': 6.814907249477245,
#  '2小': 1.8294226707609804,
#  '2小时': 6.960861162100325,
#  '小时': 5.306484649098502,
#  '中国陆': 5.174840415333736,
#  '中国陆军': 6.113938773308123,
#  '中国陆军也': 9.456805907609635,
#  '中国陆军也在': 11.734073192619391,
#  '国陆': 3.2540892174556384,
#  '国陆军': 6.3482373852000284,
#  '国陆军也': 8.873659622264018,
#  '国陆军也在': 10.457779726713829,
#  '国陆军也在对': 11.84407408783372,
#  '陆军也': 6.311098325638866,
#  '陆军也在': 7.489753321980513,
#  '陆军也在对': 10.711172725686978,
#  '陆军也在对C': 14.688983471653128,
#  '军也': 1.8280412968722641,
#  '军也在': 4.043997956616143,
#  '军也在对': 8.14622336822544,
#  '军也在对C': 13.302689110533237,
#  '军也在对CH': 14.218979842407391,
#  '也在': 2.7364958340809973,
#  '也在对': 4.2086325860577976,
#  '也在对C': 9.979453270340793,
#  '也在对CH': 12.8326854812875,
#  '也在对CH—': 14.506661914859173,
#  '反坦克导弹重': 12.609541929973291,
#  '坦克导弹重': 11.82108456960902,
#  '坦克导弹重4': 12.514231750168966,
#  '克导弹重': 11.82108456960902,
#  '克导弹重4': 12.514231750168966,
#  '克导弹重45': 13.207378930728911,
#  '导弹重': 7.508862824331103,
#  '导弹重4': 7.796544896782883,
#  '导弹重45': 10.124635280185291,
#  '导弹重45公': 14.506661914859173,
#  '弹重': 1.1122623510310516,
#  '弹重4': 7.251541561264081,
#  '弹重45': 9.83695320773351,
#  '弹重45公': 14.218979842407391,
#  '弹重45公斤': 14.218979842407391,
#  '重4': 1.4431845940710184,
#  '重45': 5.7579867006793535,
#  '重45公': 9.933670627235315,
#  '重45公斤': 11.663692395857591,
#  '45': 4.425338022705292,
#  '45公': 4.2189953145873735,
#  '45公斤': 11.342594326485967,
#  '5公': 3.9859265938557282,
#  '5公斤': 9.69634244092915,
#  '公斤': 7.840512451040066,
#  '射程': 5.315908582800329,
#  '射程8': 8.615017703033402,
#  '射程8公': 8.615017703033402,
#  '射程8公里': 9.909859978541597,
#  '程8': 0.1091230916497412,
#  '程8公': 8.16161052041169,
#  '程8公里': 9.909859978541597,
#  '8公': 3.4000065485817728,
#  '8公里': 7.91203801739818,
#  '惯性': 6.483479522829046,
#  '惯性加': 11.122271651513397,
#  '惯性加G': 12.864434179602082,
#  '惯性加GP': 12.864434179602082,
#  '惯性加GPS': 12.966216873912023,
#  '性加': -0.2101241418027792,
#  '性加G': 10.69261931779123,
#  '性加GP': 12.864434179602082,
#  '性加GPS': 12.966216873912023,
#  '性加GPS诱': 15.605274203527282,
#  '加G': 2.2568531250707218,
#  '加GP': 10.169371174026683,
#  '加GPS': 12.609541929973291,
#  '加GPS诱': 15.605274203527282,
#  '加GPS诱导': 15.605274203527282,
#  'GP': 7.997556312215831,
#  'GPS': 10.335944373852497,
#  'GPS诱': 12.864434179602082,
#  'GPS诱导': 12.864434179602082,
#  'PS': 7.130818903289763,
#  'PS诱': 10.169371174026683,
#  'PS诱导': 10.663631780917978,
#  'S诱': 5.894688987329296,
#  'S诱导': 7.796544896782883,
#  '诱导': 6.06615437393112,
#  '1.': 4.793548252307827,
#  '1.1': 5.400224787542838,
#  '1.1马': 11.083485626478241,
#  '1.1马赫': 11.094414697010432,
#  '1.1马赫射': 16.298421384087227,
#  '.1': 4.132489386299382,
#  '.1马': 9.100986029990636,
#  '.1马赫': 11.094414697010432,
#  '.1马赫射': 16.298421384087227,
#  '.1马赫射速': 16.298421384087227,
#  '1马': -0.6998581205719644,
#  '1马赫': 11.094414697010432,
#  '1马赫射': 16.298421384087227,
#  '1马赫射速': 16.298421384087227,
#  '马赫': 7.084244630442761,
#  '马赫射': 8.822515414719831,
#  '马赫射速': 10.530100388293455,
#  '赫射': 3.411011015956606,
#  '赫射速': 8.921913257761007,
#  '射速': 3.541094669701227,
#  '其他': 5.570956627220334,
#  '其他权': 8.039998921628351,
#  '其他权威': 9.452541508823177,
#  '其他权威消': 16.298421384087227,
#  '其他权威消息': 16.298421384087227,
#  '他权': 0.19781661057902386,
#  '他权威': 9.452541508823177,
#  '他权威消': 16.298421384087227,
#  '他权威消息': 16.298421384087227,
#  '他权威消息来': 16.298421384087227,
#  '权威消': 9.052053303984767,
#  '权威消息': 9.052053303984767,
#  '权威消息来': 13.813514734299227,
#  '权威消息来源': 13.995836291093182,
#  '威消': 2.4912454629130107,
#  '威消息': 8.426728719763583,
#  '威消息来': 13.813514734299227,
#  '威消息来源': 13.995836291093182,
#  '威消息来源还': 16.298421384087227,
#  '消息来源还': 14.101196806751007,
#  '消息来源还透': 14.101196806751007,
#  '息来源还': 13.813514734299227,
#  '息来源还透': 13.813514734299227,
#  '息来源还透露': 13.813514734299227,
#  '来源还': 7.229299014026582,
#  '来源还透': 9.970484600358033,
#  '来源还透露': 10.793089848154864,
#  '来源还透露了': 15.199809095419118,
#  '源还': 0.7391228063027426,
#  '源还透': 9.970484600358033,
#  '源还透露': 10.793089848154864,
#  '源还透露了': 15.199809095419118,
#  '源还透露了更': 16.298421384087227,
#  '还透': 3.5844473863083097,
#  '还透露': 10.018025545127033,
#  '还透露了': 11.46213947713575,
#  '还透露了更': 14.506661914859173,
#  '还透露了更多': 14.506661914859173,
#  '透露': 9.1954202973302,
#  '透露了': 8.024574451302719,
#  '透露了更': 9.970484600358033,
#  '透露了更多': 9.970484600358033,
#  '透露了更多的': 10.460690936921287,
#  '露了': 3.2880876960505643,
#  '露了更': 5.5293891753948925,
#  '露了更多': 7.600574692977732,
#  '露了更多的': 10.460690936921287,
#  '露了更多的阿': 16.298421384087227,
#  '了更': 3.0780840031372128,
#  '了更多': 6.056377302412033,
#  '了更多的': 8.456961216977147,
#  '了更多的阿': 11.809785014355088,
#  '了更多的阿联': 13.353982404920787,
#  '更多': 5.5125000041531935,
#  '更多的': 7.569602589958271,
#  '更多的阿': 8.363907920204964,
#  '更多的阿联': 10.451982609029503,
#  '更多的阿联酋': 13.002584518082898,
#  '多的': 2.296588294603518,
#  '多的阿': 3.7087543948671056,
#  '多的阿联': 8.201603913514909,
#  '多的阿联酋': 13.002584518082898,
#  '多的阿联酋进': 16.298421384087227,
#  '的阿': 1.6430291734582272,
#  '的阿联': 4.309783615404282,
#  '的阿联酋': 12.931125554100753,
#  '的阿联酋进': 16.298421384087227,
#  '的阿联酋进口': 16.298421384087227,
#  '阿联': 4.322468774931598,
#  '阿联酋': 12.700601895488921,
#  '阿联酋进': 12.772060859471067,
#  '阿联酋进口': 12.772060859471067,
#  '阿联酋进口“': 14.688983471653128,
#  '联酋': 8.130144949532763,
#  '联酋进': 8.201603913514909,
#  '联酋进口': 9.032292604530776,
#  '联酋进口“': 14.688983471653128,
#  '联酋进口“翼': 16.298421384087227,
#  '酋进': 3.900270764099317,
#  '酋进口': 8.960833640548632,
#  '酋进口“': 14.688983471653128,
#  '酋进口“翼': 16.298421384087227,
#  '酋进口“翼龙': 16.298421384087227,
#  '进口“': 6.3512758622116365,
#  '进口“翼': 9.88824650212106,
#  '进口“翼龙': 13.408049626191064,
#  '进口“翼龙”': 13.525832661847446,
#  '口“': 0.6056494240987351,
#  '口“翼': 8.971955770246906,
#  '口“翼龙': 12.491758894316908,
#  '口“翼龙”': 12.609541929973291,
#  '口“翼龙”攻': 16.298421384087227,
#  '“翼': 3.2312234033767067,
#  '“翼龙': 8.98745353205022,
#  '“翼龙”': 10.073120656126292,
#  '“翼龙”攻': 13.73347202662569,
#  '“翼龙”攻击': 13.73347202662569,
#  '翼龙': 5.9531582237619185,
#  '翼龙”': 6.921042312181608,
#  '翼龙”攻': 12.021755265071173,
#  '翼龙”攻击': 12.155286657695695,
#  '翼龙”攻击无': 15.199809095419118,
#  '龙”': 5.299365882797764,
#  '龙”攻': 7.393519806152084,
#  '龙”攻击': 8.32733563058162,
#  '龙”攻击无': 15.199809095419118,
#  '龙”攻击无人': 15.605274203527282,
#  '”攻': 1.4204416512789877,
#  '”攻击': 8.193804237957098,
#  '”攻击无': 13.120367553739282,
#  '”攻击无人': 13.525832661847446,
#  '”攻击无人机': 13.525832661847446,
#  '攻击无人机的': 11.248565376837691,
#  '击无人机的': 10.843100268729525,
#  '击无人机的状': 15.605274203527282,
#  '无人机的': 8.219076006485565,
#  '无人机的状': 9.606337641580598,
#  '无人机的状况': 9.606337641580598,
#  '人机的': 4.527367833533741,
#  '人机的状': 6.625857570184271,
#  '人机的状况': 9.063522963772396,
#  '机的': 2.4155602395548663,
#  '机的状': 3.255672805922309,
#  '机的状况': 9.063522963772396,
#  '的状': 2.859613964870668,
#  '的状况': 7.717502501790445,
#  '状况': 7.532218754295908,
#  '这种': 5.68617106148949,
#  '这种无': 6.595521197151947,
#  '这种无人': 6.700881712809773,
#  '这种无人机': 9.620498644570096,
#  '这种无人机在': 10.287154209683065,
#  '种无': 3.1160485387406993,
#  '种无人': 6.520497054526445,
#  '种无人机': 9.310343716266257,
#  '种无人机在': 9.776328585917074,
#  '种无人机在后': 12.714902445631118,
#  '无人机在': 8.258296719638848,
#  '无人机在后': 9.606337641580598,
#  '无人机在后来': 9.606337641580598,
#  '人机在': 4.987432120876918,
#  '人机在后': 6.990409984937599,
#  '人机在后来': 8.521886355901987,
#  '人机在后来的': 10.46947576647702,
#  '机在': 2.289708353217083,
#  '机在后': 4.184307789670619,
#  '机在后来': 6.536151833466637,
#  '机在后来的': 9.175554725488144,
#  '机在后来的多': 15.605274203527282,
#  '在后': 1.1918464115396756,
#  '在后来': 5.004675462502249,
#  '在后来的': 6.257783993403866,
#  '在后来的多': 12.687503471443003,
#  '在后来的多次': 13.302689110533237,
#  '后来': 3.545208076644443,
#  '后来的': 3.4309502563116885,
#  '后来的多': 7.55808464135678,
#  '后来的多次': 9.632737666304818,
#  '后来的多次打': 13.253898946363805,
#  '来的': 2.5173016465255653,
#  '来的多': 2.2734719564253214,
#  '来的多次': 7.650024507055646,
#  '来的多次打': 13.253898946363805,
#  '来的多次打靶': 16.298421384087227,
#  '的多': 1.4146849050388388,
#  '的多次': 4.303635361888485,
#  '的多次打': 8.298071888762543,
#  '的多次打靶': 11.85577012759691,
#  '的多次打靶过': 16.298421384087227,
#  '多次': 4.688750113425343,
#  '多次打': 5.654664543922419,
#  '多次打靶': 9.710871369262431,
#  '多次打靶过': 15.199809095419118,
#  '多次打靶过程': 15.199809095419118,
#  '次打': 2.953882542861827,
#  '次打靶': 7.764961220207118,
#  '次打靶过': 13.253898946363805,
#  '次打靶过程': 13.253898946363805,
#  '次打靶过程中': 13.253898946363805,
#  '打靶': 5.902032600069516,
#  '打靶过': 8.557756982169986,
#  '打靶过程': 8.557756982169986,
#  '打靶过程中': 10.472421276706777,
#  '打靶过程中不': 15.605274203527282,
#  '靶过': 2.185231394220896,
#  '靶过程': 8.271924445141815,
#  '靶过程中': 10.472421276706777,
#  '靶过程中不': 15.605274203527282,
#  '靶过程中不太': 16.298421384087227,
#  '过程': 5.895715055940599,
#  '过程中': 7.551951487653333,
#  '过程中不': 6.981021939817637,
#  '过程中不太': 10.050378509578799,
#  '过程中不太顺': 16.298421384087227,
#  '程中': 4.250637049674336,
#  '程中不': 4.976087579137486,
#  '程中不太': 8.271924445141815,
#  '程中不太顺': 15.605274203527282,
#  '程中不太顺利': 15.605274203527282,
#  '中不': 0.9794858725941683,
#  '中不太': 4.594759863722026,
#  '中不太顺': 12.309437337522953,
#  '中不太顺利': 12.309437337522953,
#  '不太': 2.9517532515659908,
#  '不太顺': 6.837789328877823,
#  '不太顺利': 7.818307200912411,
#  '太顺': 2.3751538841896718,
#  '太顺利': 7.818307200912411,
#  '顺利': 7.393542357145519,
#  '原因': 6.823737275730675,
#  '原因不': 8.10419207926741,
#  '原因不明': 8.797339259827355,
#  '因不': 0.9860658910286769,
#  '因不明': 6.704452598612055,
#  '不明': 3.3260394537790963,
#  '中东': 3.8816990938802753,
#  '中东地': 6.338655897812608,
#  '中东地区': 7.875758676517223,
#  '中东地区的': 9.26491489979953,
#  '中东地区的酷': 11.46213947713575,
#  '东地': 3.322980595616255,
#  '东地区': 7.875758676517223,
#  '东地区的': 9.216975437510412,
#  '东地区的酷': 11.349661493709059,
#  '东地区的酷热': 11.349661493709059,
#  '地区的酷': 7.7653548435147,
#  '地区的酷热': 9.228547255628655,
#  '地区的酷热天': 15.605274203527282,
#  '区的酷': 7.588076604065442,
#  '区的酷热': 9.228547255628655,
#  '区的酷热天': 14.506661914859173,
#  '区的酷热天气': 14.506661914859173,
#  ...}

# %%
from collections import Counter 

# 计算候选单词的邻字熵
def compute_entropy(candidate_words_characters):
    words_entropy = {}
    with tqdm(candidate_words_characters.items(), total=len(candidate_words_characters), desc="Counting entropy") as pbar:
        for word, characters in pbar:
            character_freq = Counter(characters)  # 统计邻字的出现分布
            # 根据出现分布计算邻字熵
            words_entropy[word] = sum(map(lambda x: - x/len(characters) * math.log(x/len(characters)) , character_freq.values())) 
    return words_entropy

# %%
words_left_entropy = compute_entropy(candidate_words_left_characters)
words_right_entropy = compute_entropy(candidate_words_right_characters)
# Out:
# Counting entropy: 100%|██████████| 5281978/5281978 [00:17<00:00, 298766.25it/s]
# Counting entropy: 100%|██████████| 5281978/5281978 [00:17<00:00, 298936.78it/s]

# %% [markdown]
# ### 设定各指标的阈值，根据其值获取最终的新词结果

# %%
# 根据各指标阈值获取最终的新词结果
def get_newwords(candidate_words_freq,
                               words_pmi,
                               words_left_entropy,
                               words_right_entropy,
                               words_freq_limit=4,
                               pmi_limit=5,
                               entropy_limit=1):
    # 在每一项指标中根据阈值进行筛选
    candidate_words = [k for k, v in candidate_words_freq.items() if v >= words_freq_limit]
    candidate_words_pmi = [k for k, v in words_pmi.items() if v >= pmi_limit]
    candidate_words_left_entropy = [k for k, v in words_left_entropy.items() if v >= entropy_limit]
    candidate_words_right_entropy = [k for k, v in words_right_entropy.items() if v >= entropy_limit]
    # 对筛选结果进行合并
    return list(set(candidate_words).intersection(candidate_words_pmi, candidate_words_left_entropy, candidate_words_right_entropy))

# %%
# 可以不断调参数来达到想要的结果
new_words = get_newwords(candidate_words_freq,
                         words_pmi,
                         words_left_entropy,
                         words_right_entropy,
                         words_freq_limit= 2,
                         pmi_limit=3,
                         entropy_limit=1)
print(len(new_words))
new_words
# Out:
# 113636
# ['以切实',
#  '不断创',
#  '撰写的',
#  '救援训练',
#  '搜索前进',
#  '35分钟',
#  '0多部',
#  '月14',
#  '按照中国',
#  '党委会',
#  '工作总',
#  '才是正',
#  '济南军区空',
#  '们……',
#  '新华社专',
#  '媒体披',
#  '提到的',
#  '仍在继续',
#  '美俄关',
#  '官兵家属',
#  '2004年1',
#  '在墨西哥',
#  '199',
#  '名队员',
#  '途径就是',
#  '雷达和',
#  '现场警戒',
#  '只有把',
#  '已有1',
#  '军事报',
#  '带着家',
#  '处处有',
#  '口号是',
#  '信息优势',
#  '抗美援朝战争',
#  '还是个',
#  '无声',
#  '利用战',
#  '“边防',
#  '包括日本',
#  '甚至为',
#  '有效载荷50',
#  '已经摆',
#  '战术作',
#  '的成功经',
#  '演习过程',
#  '卸货',
#  '访沪',
#  '稳定性和',
#  '了《军',
#  '不失为一',
#  '进行沟',
#  '不可分',
#  '通讯中',
#  '年过去',
#  '体来说',
#  '两年多来',
#  '的能力',
#  '的英语',
#  '语言',
#  '中日之间',
#  '代理排长',
#  '一起完成',
#  '先进的',
#  '李春福',
#  '坦克与',
#  'ker',
#  '因为要',
#  '导的军',
#  '被大家称为“',
#  '袖子',
#  '诺夫表',
#  '公司宣布',
#  '在指挥',
#  '经过几个',
#  '7月1日上午',
#  '请上级',
#  '个纵队',
#  '被请上',
#  '埃及首都开罗',
#  '查找原',
#  '美国的意',
#  '军人就',
#  '的码头',
#  '工业公司的',
#  '很感兴',
#  '国栋',
#  '”6月15',
#  '没有错',
#  '队认真',
#  '率和',
#  '本国领土',
#  '特约记者王',
#  '租金问题',
#  '采取平',
#  '关于在',
#  '内地的',
#  '100公里',
#  '中央司令部',
#  '如今他',
#  '北某',
#  '4.1',
#  '拣选',
#  '以降低',
#  '边陲的',
#  '0艘船',
#  '可以享受到',
#  '李富',
#  '人工作',
#  '情动态',
#  '官兵成',
#  '报告的',
#  '了一套',
#  '发展做出了',
#  '7月3日电',
#  '着不断',
#  '愈勇',
#  '了项目',
#  '贡献自己的',
#  '做任何',
#  '霍姆斯地区',
#  '婀娜',
#  '0万',
#  '勇于创新',
#  '养工作',
#  '战斗能力',
#  '正在研制',
#  '豪华',
#  '4亿元',
#  '南海合作',
#  '在塔吉克斯坦',
#  '导弹技术',
#  '获得大',
#  '积极为',
#  '安全相',
#  '复杂',
#  '中广网',
#  '夏夜兵车如墨',
#  '只有30',
#  '组组',
#  '现在就',
#  '的最大障',
#  '已经打',
#  '于飞行',
#  '航空公司',
#  '大力支持',
#  '”一词',
#  '重要活动',
#  '告知',
#  '守着',
#  '弯路',
#  '哈罗铁路',
#  '开始了新一',
#  '大奖赛',
#  '美妙',
#  '兹·',
#  '技术的进步',
#  '不完的',
#  '的争夺',
#  '发帖',
#  '期举',
#  '中国工农红军',
#  '中的重要',
#  '需要”',
#  '的一名',
#  '一个动作',
#  '奋发向上的',
#  '漫长',
#  '靠泊',
#  '负责确保',
#  '人数更',
#  '没想',
#  '消费',
#  '地进入',
#  '黏膜',
#  '功能完善',
#  '转移至安全地',
#  '的愤',
#  '一筐',
#  '褚琴',
#  '相互学习',
#  '次竞',
#  '投送能力',
#  '抗战时',
#  '的飞行任务',
#  '深受大家',
#  '冲之鸟岛',
#  '国之后',
#  '游击',
#  '补给品',
#  '近10年',
#  '地势险',
#  '居住环境',
#  '交响',
#  '00美',
#  '动力系统',
#  '方针政',
#  '美国空军',
#  '点建',
#  '快速出',
#  ')新华网',
#  '一个农村',
#  '机概念',
#  '进行测',
#  '部队为',
#  '还应该',
#  '造就了',
#  '出现故障',
#  '心理训练',
#  '军交运输',
#  '30多万',
#  '的合击',
#  '能”的',
#  '安全隐患',
#  '进一步规范',
#  '军民两用技术',
#  '现代化计',
#  '的特种作战',
#  '武器分',
#  '的遏制',
#  '驻冲绳',
#  '了5次',
#  '心”活动',
#  '的武器出口',
#  '基础;',
#  '统计显',
#  '巍峨',
#  '严管理',
#  '美国方面的',
#  '的刻苦训',
#  '顺利实',
#  '性格内',
#  '完成空中',
#  '在推进',
#  '访问美',
#  '隔着',
#  '陡峭的',
#  '中得到',
#  '战斗力“',
#  '结合实',
#  '?这',
#  '作战意',
#  '但美国《',
#  '官兵体能',
#  '停放',
#  '度提升',
#  '的价值追',
#  '牢记使命',
#  '的机动',
#  '7000米深',
#  '稳定发展的',
#  '官兵恳谈',
#  '2005年7',
#  '而今天',
#  '性成果',
#  '军事对抗',
#  '立即组织',
#  '市市',
#  '钓鱼比',
#  '报名参加了',
#  '锁定目',
#  '日20时',
#  '受训指挥机关',
#  '的歼-15',
#  '提及中国',
#  '4个小时的',
#  '深入交',
#  '抢修等',
#  '9日电(记者',
#  '试验过程中',
#  '开赴',
#  '个军事',
#  '01号航天员',
#  '面对这个',
#  '弹簧腿',
#  '全部实现',
#  '以武装',
#  '环境进行',
#  '的坚定',
#  '新型自行火炮',
#  '方面的原因',
#  '在政治和',
#  '安全问题',
#  '的青岛',
#  '军功章',
#  '与“蛟龙”号',
#  '蹲点时',
#  '和个人',
#  '在国内的',
#  '军工企业和',
#  '厄海军学',
#  '真正的“',
#  '政治处',
#  '迅速做出反',
#  '要拿',
#  '接壤的',
#  '惊呆了',
#  '作战企图',
#  '时提醒',
#  '节;',
#  '4000余人',
#  '理论基础扎实',
#  '的数十',
#  '级地震',
#  '的反华',
#  '更加深',
#  '代表会',
#  '但迄今',
#  '神舟八号飞船',
#  '“队列',
#  '南越',
#  '识别并',
#  '发挥不',
#  '模式的成',
#  '为“新',
#  '等国际',
#  '将引',
#  '带来重大',
#  '于20',
#  '斯洛',
#  '进行了猛烈',
#  '父爱',
#  '西班牙人',
#  '同时推',
#  '国际惯',
#  '不要怕',
#  '传统上',
#  '迪·',
#  '发射基地',
#  '这种策略',
#  '战役中',
#  '时赶',
#  '不会想到',
#  '但一旦',
#  '作战时',
#  '转换',
#  '通告',
#  '首次采用',
#  '的手法',
#  '扩大海上',
#  '任务都',
#  '需要在地面',
#  '42.',
#  '为每分钟',
#  '色彩的',
#  '既成事',
#  '队中服役',
#  '世界大国',
#  '的巡逻机',
#  '中国20',
#  '国内问题',
#  '机日前',
#  '单位为',
#  '5日举行',
#  '于帮助',
#  '一个标',
#  '的竞争',
#  '在201',
#  '证实',
#  '引起热',
#  '卡梅伦',
#  '花费',
#  '学习充电',
#  '2010年8',
#  '东华',
#  '寇俊青',
#  '的目的是',
#  '昨天下',
#  '突然出现故障',
#  '试点任',
#  '既可以',
#  '饮食习惯',
#  '坚持把',
#  '联合国观察员',
#  '中国在三沙',
#  '”级潜艇将',
#  '尔诺',
#  '重庆市',
#  '火炬手',
#  '中有一',
#  '军队不得不',
#  '玲)',
#  '办法和',
#  'ra',
#  '战斗后勤',
#  '就这样',
#  '制以及',
#  '作训股参谋',
#  '落实上',
#  '·格',
#  '一个年',
#  '2小时',
#  '磨砺了',
#  '的李文',
#  '1月30日',
#  '超介绍',
#  '应知应会',
#  '1日宣',
#  '成为国家',
#  '了《',
#  '”导弹的',
#  '海军首批',
#  '朱德',
#  '无论',
#  '征途',
#  '在国家',
#  '使用过',
#  '学习“',
#  '水和镜子',
#  '梁艺钟',
#  '中国推',
#  '了检查',
#  '的忧患意识',
#  '高校的',
#  '会议上',
#  '柴油发动',
#  '电子对抗',
#  '楷模',
#  '此次军演',
#  '焦急',
#  '国第2',
#  '向叙利亚当局',
#  '德罗',
#  '造船厂',
#  '想让',
#  '听课的',
#  '例行检查',
#  '千里机动',
#  '6月18日下',
#  '紧盯',
#  '强调不',
#  '出现失',
#  '就非常',
#  '审美',
#  '秒之内',
#  '壕沟',
#  '约束自己',
#  '这个夏',
#  '不逊',
#  '区北部',
#  '无疑是',
#  '部队后',
#  '轻型护卫舰',
#  '保卫人民',
#  '运-8',
#  '数倍',
#  '目标是建立',
#  '女飞行',
#  '靠创新',
#  '作出贡献',
#  '部队到',
#  '当地时间2',
#  '的外交努力',
#  '了40多',
#  '按照新',
#  '为中国航',
#  '隐性缺陷',
#  '北极地区',
#  '千钧一发之际',
#  '“全家福”',
#  '探讨如何',
#  '农作物种子',
#  '拥有这',
#  '中国移动将',
#  '的租金',
#  '乌克兰',
#  '7月4日',
#  '俄罗斯有',
#  '……1',
#  '9.5',
#  '进行深入的',
#  '6月18',
#  '实际上只',
#  '等离子体',
#  '他已经',
#  '2010年夏',
#  '官兵围绕“',
#  '倾心',
#  '指挥协调',
#  '极低',
#  '近几',
#  '正风气',
#  '而刘旺',
#  '差很',
#  '才得知',
#  '印度购买',
#  '问卷调',
#  '车进行',
#  '标准排水量',
#  '的崭新篇章',
#  '网络语',
#  '“一国两制”',
#  '监禁',
#  '影响很大',
#  '结合的一',
#  '到山东',
#  '的奖章',
#  '士官学',
#  '但是美国',
#  '兵训练中',
#  '越来越强',
#  '00余万',
#  '嘴里',
#  '海底进行',
#  '高举过头',
#  '指挥警',
#  '见她',
#  '为世界最',
#  '健康向上',
#  '根植',
#  '向实战化',
#  '虽然美国',
#  '准备和',
#  '一个案例',
#  '千余台',
#  '叛逃的',
#  '时间最长的一',
#  '美军将在',
#  '速行进',
#  '修养和',
#  '的袋子',
#  '的解决办法',
#  '越来越远',
#  '和财',
#  '议会',
#  '年第一',
#  '多项重大',
#  '经过几',
#  '官兵整齐列队',
#  '“永远',
#  '大队和',
#  '方式的转',
#  '然后再',
#  '版本',
#  'ho',
#  '长距离',
#  '日前被',
#  '海外部署',
#  '舰海军',
#  '物质奖',
#  '我们都',
#  '史上首次',
#  '跑过',
#  '中国被',
#  '者却',
#  '退伍后',
#  '!祝',
#  '工作开',
#  '现代医学',
#  '中国则',
#  '兵力达',
#  '大的兴',
#  '通过专',
#  '当时正在',
#  '太原',
#  '的教育训练',
#  '家园的',
#  '夺得第',
#  '与此同时',
#  '年全球',
#  '4日',
#  '”21日',
#  '1000米级',
#  '首长',
#  '个类似',
#  '一个正',
#  '把我们的',
#  '了退休',
#  '基因',
#  '7月13日',
#  '编写',
#  '时隔',
#  '大会',
#  '湄公河惨案的',
#  '其携带的',
#  '凭借',
#  '同时展',
#  '中国与东盟',
#  '中国社科院',
#  '司令部(',
#  '辆T-',
#  ')进入',
#  '什么叫',
#  '团奉命',
#  '国军队将',
#  '稍有不慎',
#  '该如何',
#  '士兵',
#  'ce',
#  '奉献的',
#  '军组织',
#  '天下之',
#  '飞速发',
#  '到底是什么',
#  '机抵达',
#  '黄继光',
#  '的士官班',
#  '很快掌握了',
#  '蹲点调研',
#  '0-200',
#  '为什麽',
#  '跟头',
#  '的火炮',
#  '导弹”',
#  '官兵参加',
#  '带来的好处',
#  '动力',
#  '携带',
#  '队始终',
#  '拉尔',
#  '与发展',
#  '这些装置',
#  '的安全威胁',
#  '部队野外驻训',
#  '“让我',
#  '部门也',
#  '包括可',
#  '写一篇文',
#  '分不开',
#  '人才培养方案',
#  '的陆地补给线',
#  '政府出面',
#  '解放军在',
#  '惟妙惟',
#  '解难题”活',
#  '闫宏斌',
#  '从细',
#  '争夺的',
#  '旅政治部主任',
#  '是新疆',
#  '超级大国',
#  '》18日',
#  '引发了',
#  '以人为',
#  '武装工作',
#  '“请进',
#  '个角落',
#  '美国会',
#  '乐观的心',
#  '白热',
#  '从而在',
#  '又被',
#  '文化生',
#  '艺术形式',
#  '树立一',
#  '望从',
#  '黄海某海域',
#  '“敬礼!”',
#  '婚姻',
#  '对德国',
#  '思想素质',
#  '在电话里',
#  '保密的',
#  '“当兵不习',
#  '转运的',
#  '其国防',
#  '作战指挥中心',
#  '全国重点',
#  '曲”',
#  '并祝',
#  '依靠自主创',
#  '正确方',
#  '军事素质',
#  '全区域',
#  '官兵创',
#  '机投放',
#  '有明显的',
#  '一般情况下',
#  '应对未来',
#  '计划:',
#  '作战态',
#  '我可能',
#  '训结束后',
#  '今年中',
#  '部队会',
#  '构件',
#  '岗位实践',
#  '腹泻',
#  '交出了一份',
#  '通过这个',
#  '回家”',
#  '进一步凝聚',
#  '是对我们',
#  '但美国政府',
#  '种理论',
#  '指挥平台',
#  '各种复杂',
#  '的情绪',
#  '型导弹可',
#  '劲头',
#  '开展军',
#  '无法接受',
#  '服役后',
#  '每秒1',
#  '遵纪守法',
#  '了红军',
#  '掀起',
#  '亚沙会期',
#  '被国家',
#  '封锁能',
#  '技术装',
#  '和谐融',
#  '的广泛关注',
#  '到同样',
#  '是为了',
#  '群岛海',
#  '使用管理',
#  '解决方案',
#  '的代价',
#  '亮点',
#  '相冲突',
#  '“十年',
#  '成为了官兵',
#  '到他的',
#  '一本好书',
#  '月初宣布',
#  '更灵',
#  '国的军队',
#  '知远/杜和',
#  '动!”',
#  '剧烈',
#  '为今年',
#  '的话称',
#  '形式多样',
#  '工程师王',
#  '扑向',
#  '守护神”',
#  '水平是',
#  '美方对',
#  '在某些情况',
#  '今年5',
#  '的骄傲!”',
#  '任务开展',
#  '称这一',
#  '全力支持',
#  '比上届',
#  '先进的“',
#  '中发挥',
#  '到达海',
#  '男兵',
#  '解说',
#  '但它们',
#  '合到一起',
#  '无法确',
#  '美国的出口',
#  '道:“我',
#  '打气',
#  '之外',
#  '荣立二等功一',
#  '经过他的',
#  '位于大',
#  '可重复使用',
#  '东门',
#  '期限',
#  '传统的战',
#  '地拍',
#  '开发出',
#  '西方媒体称',
#  '工作环',
#  '多的时间',
#  '方面军的',
#  '还能为',
#  '满了人',
#  '赶到医院',
#  '视频显示',
#  '400毫米',
#  'GE-',
#  '雷达站',
#  '受到官兵',
#  '“东京购岛”',
#  '了最近',
#  '显得十分',
#  '日)在',
#  '这是军',
#  '方案和',
#  '和民间',
#  '个课目的',
#  '完毕',
#  '和优势',
#  '让他明',
#  '19个',
#  '执行安南',
#  '所知的',
#  '优秀的飞行',
#  '接受的',
#  '据信',
#  '快速出击',
#  '日益增强',
#  '向韩国',
#  '施工中',
#  '”的冲',
#  '方面',
#  '通讯',
#  '合理搭配',
#  '日常战备工',
#  '的先进性',
#  '报道:7月上',
#  '数据库',
#  '个国家的1',
#  '6个小时',
#  '”报告',
#  '第五代战斗机',
#  '的一部',
#  '太低',
#  '轻武器博物馆',
#  '的毅力',
#  '有超过1',
#  '量血压',
#  '人的人生',
#  '机将被',
#  '警察和军',
#  '惨烈',
#  '规范各',
#  '谈论',
#  '系统模',
#  '反潜的',
#  '是一位',
#  '海上军',
#  '作品',
#  '建交20年',
#  '”的角色',
#  '海底的',
#  '渔民的',
#  '00磅)',
#  '管理',
#  '不尽相同',
#  '操场',
#  '的突发情',
#  '着白色',
#  '袭击者',
#  '炎炎烈日',
#  '航期间',
#  '军方宣布',
#  '半岛和',
#  '世界最',
#  '保障性住',
#  '座舱',
#  '”伊朗',
#  '是亚太国',
#  '渐渐散去',
#  '如画',
#  '飞行数',
#  '着班长',
#  '韩防卫事业厅',
#  '30发',
#  '(40',
#  '西北岛屿',
#  '文莱',
#  '的加速度',
#  '的贡献',
#  '方面则',
#  '达人”',
#  '使用新',
#  '教方法',
#  '理问',
#  '拆迁',
#  '曾通过',
#  '伊拉克军',
#  '薛凯',
#  '月宣布',
#  '类似',
#  '三分之一在',
#  '背影',
#  '风浪稍',
#  '部有关负责人',
#  '自行研制的',
#  '保释规定',
#  '人不知',
#  '这是第',
#  '他们说',
#  '的消息人士',
#  'ros',
#  '协调区',
#  '威慑力的',
#  '2颗',
#  '引经据典',
#  '造成重大',
#  '舟山群岛',
#  '人员发现',
#  '间发起',
#  '清明节',
#  '当天晚上',
#  '上台',
#  '国媒体',
#  '学教',
#  '需求和',
#  '党委和',
#  '两位老人',
#  '的巨幅',
#  '在同类',
#  '受挫',
#  '分泌',
#  '运输机飞行',
#  '向前进',
#  '的饮',
#  '到2020',
#  '数量分别',
#  '在全国',
#  '理论创新',
#  '信仰和',
#  '的政治',
#  '队奉命',
#  '抓扣',
#  '诗《',
#  '国家防总',
#  '了18',
#  '等方面',
#  '”的消息',
#  '了第二',
#  '本地区的',
#  '把活动',
#  '50%的',
#  '邹教授',
#  '所有权',
#  '团队精',
#  '任务的是',
#  '特战精',
#  '开相关',
#  '岩国',
#  '风声',
#  '上任后',
#  '集资',
#  '不负责任',
#  '中国载人深潜',
#  '以这样',
#  '速度很快',
#  '个海军基地',
#  '舰经过',
#  '都有新',
#  '奥运安保',
#  '了和谐',
#  '克洛泽',
#  '刘旺',
#  '找矿',
#  'si',
#  '力量中',
#  '部队大',
#  '四野',
#  '押运途中',
#  '祭出',
#  '赫章',
#  '坚守岗',
#  '持久',
#  '作品集',
#  '10余个',
#  '要定期',
#  '在近几年',
#  '万册',
#  '开花结',
#  '资料的',
#  '和现代',
#  '高质量',
#  '的驱逐',
#  '扎伊',
#  '精神在',
#  '0年代后',
#  '阳光心态',
#  '利用业余时间',
#  '大家都在',
#  '为什么',
#  '基地指挥',
#  '民族自豪感',
#  '位老',
#  '到了很',
#  '授权',
#  '市委统一安排',
#  '了具体的',
#  '飞船返回舱的',
#  '收到了',
#  '官兵热',
#  '据外媒报道',
#  '如果韩',
#  '补给',
#  '提出的要求',
#  '并荣立',
#  '年的努',
#  '献身',
#  '情变化',
#  '要求美国',
#  '了荣誉',
#  '29日宣',
#  '他们先后与',
#  '没有打',
#  '发测站',
#  '97%',
#  '作战舰',
#  '正进行',
#  '落网后',
#  '状况下',
#  '经济状况',
#  '13.5',
#  '自行车功量',
#  '理念的',
#  '的午餐',
#  '炉膛',
#  '军事关',
#  '不变的',
#  '成了一名',
#  '(Sha',
#  '舰的生',
#  ...]

# %% [markdown]
# ### 过滤掉一些不正确的新词

# %%
new_words1 = list(filter(lambda x: not re.search("[^\u4e00-\u9fa5]", x), new_words))
new_words2 = list(filter(lambda x: not re.search("[了但里的和为是]", x), new_words1))

# %%
print(len(new_words2))
new_words2
# Out:
# 75317
# ['以切实',
#  '不断创',
#  '救援训练',
#  '搜索前进',
#  '按照中国',
#  '党委会',
#  '工作总',
#  '济南军区空',
#  '新华社专',
#  '媒体披',
#  '仍在继续',
#  '美俄关',
#  '官兵家属',
#  '在墨西哥',
#  '名队员',
#  '现场警戒',
#  '只有把',
#  '军事报',
#  '带着家',
#  '处处有',
#  '信息优势',
#  '抗美援朝战争',
#  '无声',
#  '利用战',
#  '包括日本',
#  '已经摆',
#  '战术作',
#  '演习过程',
#  '卸货',
#  '访沪',
#  '进行沟',
#  '不可分',
#  '通讯中',
#  '年过去',
#  '体来说',
#  '两年多来',
#  '语言',
#  '中日之间',
#  '代理排长',
#  '一起完成',
#  '李春福',
#  '坦克与',
#  '袖子',
#  '诺夫表',
#  '公司宣布',
#  '在指挥',
#  '经过几个',
#  '请上级',
#  '个纵队',
#  '被请上',
#  '埃及首都开罗',
#  '查找原',
#  '军人就',
#  '很感兴',
#  '国栋',
#  '没有错',
#  '队认真',
#  '本国领土',
#  '特约记者王',
#  '租金问题',
#  '采取平',
#  '关于在',
#  '中央司令部',
#  '如今他',
#  '北某',
#  '拣选',
#  '以降低',
#  '可以享受到',
#  '李富',
#  '人工作',
#  '情动态',
#  '官兵成',
#  '着不断',
#  '愈勇',
#  '做任何',
#  '霍姆斯地区',
#  '婀娜',
#  '勇于创新',
#  '养工作',
#  '战斗能力',
#  '正在研制',
#  '豪华',
#  '南海合作',
#  '在塔吉克斯坦',
#  '导弹技术',
#  '获得大',
#  '安全相',
#  '复杂',
#  '中广网',
#  '夏夜兵车如墨',
#  '组组',
#  '现在就',
#  '已经打',
#  '于飞行',
#  '航空公司',
#  '大力支持',
#  '重要活动',
#  '告知',
#  '守着',
#  '弯路',
#  '哈罗铁路',
#  '大奖赛',
#  '美妙',
#  '发帖',
#  '期举',
#  '中国工农红军',
#  '一个动作',
#  '漫长',
#  '靠泊',
#  '负责确保',
#  '人数更',
#  '没想',
#  '消费',
#  '地进入',
#  '黏膜',
#  '功能完善',
#  '转移至安全地',
#  '一筐',
#  '褚琴',
#  '相互学习',
#  '次竞',
#  '投送能力',
#  '抗战时',
#  '深受大家',
#  '冲之鸟岛',
#  '国之后',
#  '游击',
#  '补给品',
#  '地势险',
#  '居住环境',
#  '交响',
#  '动力系统',
#  '方针政',
#  '美国空军',
#  '点建',
#  '快速出',
#  '一个农村',
#  '机概念',
#  '进行测',
#  '还应该',
#  '出现故障',
#  '心理训练',
#  '军交运输',
#  '安全隐患',
#  '进一步规范',
#  '军民两用技术',
#  '现代化计',
#  '武器分',
#  '驻冲绳',
#  '统计显',
#  '巍峨',
#  '严管理',
#  '顺利实',
#  '性格内',
#  '完成空中',
#  '在推进',
#  '访问美',
#  '隔着',
#  '中得到',
#  '结合实',
#  '作战意',
#  '官兵体能',
#  '停放',
#  '度提升',
#  '牢记使命',
#  '官兵恳谈',
#  '而今天',
#  '性成果',
#  '军事对抗',
#  '立即组织',
#  '市市',
#  '钓鱼比',
#  '锁定目',
#  '受训指挥机关',
#  '提及中国',
#  '深入交',
#  '抢修等',
#  '试验过程中',
#  '开赴',
#  '个军事',
#  '面对这个',
#  '弹簧腿',
#  '全部实现',
#  '以武装',
#  '环境进行',
#  '新型自行火炮',
#  '安全问题',
#  '军功章',
#  '蹲点时',
#  '厄海军学',
#  '政治处',
#  '迅速做出反',
#  '要拿',
#  '作战企图',
#  '时提醒',
#  '理论基础扎实',
#  '级地震',
#  '更加深',
#  '代表会',
#  '神舟八号飞船',
#  '南越',
#  '识别并',
#  '发挥不',
#  '等国际',
#  '将引',
#  '带来重大',
#  '斯洛',
#  '父爱',
#  '西班牙人',
#  '同时推',
#  '国际惯',
#  '不要怕',
#  '传统上',
#  '发射基地',
#  '这种策略',
#  '战役中',
#  '时赶',
#  '不会想到',
#  '作战时',
#  '转换',
#  '通告',
#  '首次采用',
#  '扩大海上',
#  '任务都',
#  '需要在地面',
#  '既成事',
#  '队中服役',
#  '世界大国',
#  '国内问题',
#  '机日前',
#  '于帮助',
#  '一个标',
#  '证实',
#  '引起热',
#  '卡梅伦',
#  '花费',
#  '学习充电',
#  '东华',
#  '寇俊青',
#  '昨天下',
#  '突然出现故障',
#  '试点任',
#  '既可以',
#  '饮食习惯',
#  '坚持把',
#  '联合国观察员',
#  '中国在三沙',
#  '尔诺',
#  '重庆市',
#  '火炬手',
#  '中有一',
#  '军队不得不',
#  '战斗后勤',
#  '就这样',
#  '制以及',
#  '作训股参谋',
#  '落实上',
#  '一个年',
#  '超介绍',
#  '应知应会',
#  '海军首批',
#  '朱德',
#  '无论',
#  '征途',
#  '在国家',
#  '使用过',
#  '梁艺钟',
#  '中国推',
#  '会议上',
#  '柴油发动',
#  '电子对抗',
#  '楷模',
#  '此次军演',
#  '焦急',
#  '向叙利亚当局',
#  '德罗',
#  '造船厂',
#  '想让',
#  '例行检查',
#  '紧盯',
#  '强调不',
#  '出现失',
#  '就非常',
#  '审美',
#  '秒之内',
#  '壕沟',
#  '约束自己',
#  '这个夏',
#  '不逊',
#  '区北部',
#  '部队后',
#  '轻型护卫舰',
#  '保卫人民',
#  '数倍',
#  '女飞行',
#  '靠创新',
#  '作出贡献',
#  '部队到',
#  '按照新',
#  '隐性缺陷',
#  '北极地区',
#  '千钧一发之际',
#  '探讨如何',
#  '农作物种子',
#  '拥有这',
#  '中国移动将',
#  '乌克兰',
#  '俄罗斯有',
#  '实际上只',
#  '等离子体',
#  '他已经',
#  '倾心',
#  '指挥协调',
#  '极低',
#  '近几',
#  '正风气',
#  '而刘旺',
#  '差很',
#  '才得知',
#  '印度购买',
#  '问卷调',
#  '车进行',
#  '标准排水量',
#  '网络语',
#  '监禁',
#  '影响很大',
#  '到山东',
#  '士官学',
#  '兵训练中',
#  '越来越强',
#  '海底进行',
#  '高举过头',
#  '指挥警',
#  '见她',
#  '健康向上',
#  '根植',
#  '向实战化',
#  '虽然美国',
#  '一个案例',
#  '千余台',
#  '美军将在',
#  '速行进',
#  '越来越远',
#  '议会',
#  '年第一',
#  '多项重大',
#  '经过几',
#  '官兵整齐列队',
#  '然后再',
#  '版本',
#  '长距离',
#  '日前被',
#  '海外部署',
#  '舰海军',
#  '物质奖',
#  '我们都',
#  '史上首次',
#  '跑过',
#  '中国被',
#  '者却',
#  '退伍后',
#  '工作开',
#  '现代医学',
#  '中国则',
#  '兵力达',
#  '通过专',
#  '当时正在',
#  '太原',
#  '夺得第',
#  '与此同时',
#  '年全球',
#  '首长',
#  '个类似',
#  '一个正',
#  '基因',
#  '编写',
#  '时隔',
#  '大会',
#  '凭借',
#  '同时展',
#  '中国与东盟',
#  '中国社科院',
#  '什么叫',
#  '团奉命',
#  '国军队将',
#  '稍有不慎',
#  '该如何',
#  '士兵',
#  '军组织',
#  '天下之',
#  '飞速发',
#  '机抵达',
#  '黄继光',
#  '蹲点调研',
#  '跟头',
#  '官兵参加',
#  '动力',
#  '携带',
#  '队始终',
#  '拉尔',
#  '与发展',
#  '这些装置',
#  '部队野外驻训',
#  '部门也',
#  '包括可',
#  '写一篇文',
#  '分不开',
#  '人才培养方案',
#  '政府出面',
#  '解放军在',
#  '惟妙惟',
#  '闫宏斌',
#  '从细',
#  '旅政治部主任',
#  '超级大国',
#  '武装工作',
#  '个角落',
#  '美国会',
#  '白热',
#  '从而在',
#  '又被',
#  '文化生',
#  '艺术形式',
#  '树立一',
#  '望从',
#  '黄海某海域',
#  '婚姻',
#  '对德国',
#  '思想素质',
#  '其国防',
#  '作战指挥中心',
#  '全国重点',
#  '并祝',
#  '依靠自主创',
#  '正确方',
#  '军事素质',
#  '全区域',
#  '官兵创',
#  '机投放',
#  '一般情况下',
#  '应对未来',
#  '作战态',
#  '我可能',
#  '训结束后',
#  '今年中',
#  '部队会',
#  '构件',
#  '岗位实践',
#  '腹泻',
#  '通过这个',
#  '进一步凝聚',
#  '种理论',
#  '指挥平台',
#  '各种复杂',
#  '型导弹可',
#  '劲头',
#  '开展军',
#  '无法接受',
#  '服役后',
#  '遵纪守法',
#  '掀起',
#  '亚沙会期',
#  '被国家',
#  '封锁能',
#  '技术装',
#  '到同样',
#  '群岛海',
#  '使用管理',
#  '解决方案',
#  '亮点',
#  '相冲突',
#  '一本好书',
#  '月初宣布',
#  '更灵',
#  '剧烈',
#  '形式多样',
#  '工程师王',
#  '扑向',
#  '美方对',
#  '在某些情况',
#  '任务开展',
#  '称这一',
#  '全力支持',
#  '比上届',
#  '中发挥',
#  '到达海',
#  '男兵',
#  '解说',
#  '合到一起',
#  '无法确',
#  '打气',
#  '之外',
#  '荣立二等功一',
#  '位于大',
#  '可重复使用',
#  '东门',
#  '期限',
#  '地拍',
#  '开发出',
#  '西方媒体称',
#  '工作环',
#  '赶到医院',
#  '视频显示',
#  '雷达站',
#  '受到官兵',
#  '显得十分',
#  '完毕',
#  '让他明',
#  '执行安南',
#  '据信',
#  '快速出击',
#  '日益增强',
#  '向韩国',
#  '施工中',
#  '方面',
#  '通讯',
#  '合理搭配',
#  '日常战备工',
#  '数据库',
#  '第五代战斗机',
#  '太低',
#  '轻武器博物馆',
#  '量血压',
#  '机将被',
#  '惨烈',
#  '规范各',
#  '谈论',
#  '系统模',
#  '海上军',
#  '作品',
#  '管理',
#  '不尽相同',
#  '操场',
#  '着白色',
#  '袭击者',
#  '炎炎烈日',
#  '航期间',
#  '军方宣布',
#  '世界最',
#  '保障性住',
#  '座舱',
#  '渐渐散去',
#  '如画',
#  '飞行数',
#  '着班长',
#  '韩防卫事业厅',
#  '西北岛屿',
#  '文莱',
#  '方面则',
#  '使用新',
#  '教方法',
#  '理问',
#  '拆迁',
#  '曾通过',
#  '伊拉克军',
#  '薛凯',
#  '月宣布',
#  '类似',
#  '三分之一在',
#  '背影',
#  '风浪稍',
#  '部有关负责人',
#  '保释规定',
#  '人不知',
#  '他们说',
#  '协调区',
#  '引经据典',
#  '造成重大',
#  '舟山群岛',
#  '人员发现',
#  '间发起',
#  '清明节',
#  '当天晚上',
#  '上台',
#  '国媒体',
#  '学教',
#  '两位老人',
#  '在同类',
#  '受挫',
#  '分泌',
#  '运输机飞行',
#  '向前进',
#  '数量分别',
#  '在全国',
#  '理论创新',
#  '队奉命',
#  '抓扣',
#  '国家防总',
#  '等方面',
#  '把活动',
#  '邹教授',
#  '所有权',
#  '团队精',
#  '特战精',
#  '开相关',
#  '岩国',
#  '风声',
#  '上任后',
#  '集资',
#  '不负责任',
#  '中国载人深潜',
#  '以这样',
#  '速度很快',
#  '个海军基地',
#  '舰经过',
#  '都有新',
#  '奥运安保',
#  '克洛泽',
#  '刘旺',
#  '找矿',
#  '力量中',
#  '部队大',
#  '四野',
#  '押运途中',
#  '祭出',
#  '赫章',
#  '坚守岗',
#  '持久',
#  '作品集',
#  '要定期',
#  '在近几年',
#  '万册',
#  '开花结',
#  '高质量',
#  '扎伊',
#  '精神在',
#  '阳光心态',
#  '利用业余时间',
#  '大家都在',
#  '基地指挥',
#  '民族自豪感',
#  '位老',
#  '授权',
#  '市委统一安排',
#  '官兵热',
#  '据外媒报道',
#  '如果韩',
#  '补给',
#  '并荣立',
#  '献身',
#  '情变化',
#  '要求美国',
#  '他们先后与',
#  '没有打',
#  '发测站',
#  '作战舰',
#  '正进行',
#  '落网后',
#  '状况下',
#  '经济状况',
#  '自行车功量',
#  '炉膛',
#  '军事关',
#  '在苏比克湾',
#  '保守',
#  '云峰',
#  '梯子',
#  '随处可',
#  '不便',
#  '希望',
#  '落实制度',
#  '获准',
#  '作战研究',
#  '尹先',
#  '评选出',
#  '日在',
#  '保钓',
#  '动能力',
#  '非常有利',
#  '所以它',
#  '其结果',
#  '机方案',
#  '运行轨道',
#  '平常心',
#  '造价',
#  '军队从',
#  '卫队已经',
#  '月工资',
#  '与社会',
#  '破拆',
#  '现在中国',
#  '索规',
#  '电磁兼容',
#  '执勤能',
#  '新式',
#  '支队警营',
#  '底数',
#  '通常被',
#  '曲艺',
#  '童世',
#  '王军说',
#  '主权争议',
#  '马晓天说',
#  '飞行队',
#  '有这样',
#  '症结',
#  '学员代表',
#  '文化氛',
#  '研发阶',
#  '国家出',
#  '次投入',
#  '老干部',
#  '影响下',
#  '观察哨',
#  '监视任',
#  '必须认识到',
#  '社会矛盾',
#  '员实施',
#  '速发',
#  '不到一个月',
#  '浪翻',
#  '签约',
#  '落实有',
#  '媒体分析认',
#  '遭遇',
#  '铺就',
#  '转型发',
#  '可快速',
#  '并投入',
#  '激光导引头',
#  '与周围',
#  '接受过',
#  '乒乓球',
#  '势力范围',
#  '日本政府认',
#  '同叙利亚',
#  '省总队',
#  '操作程序',
#  '出部队',
#  '测试发射',
#  '印度',
#  '上厕',
#  '不可行',
#  '基本制度',
#  '对他们进行',
#  '开始建',
#  '加速发展',
#  '组织严密',
#  '比赛后',
#  '返回舱落地后',
#  '对欧盟',
#  '纪念活',
#  '文化活动中',
#  '实现人',
#  '式发展',
#  '安全无',
#  '对日本',
#  '给大家',
#  '请专',
#  '遗传',
#  '被德军',
#  '华丽',
#  '提供装',
#  '示范基地',
#  '器操作员',
#  '政治考',
#  '人民军总',
#  '连队被',
#  '某装甲旅',
#  '他在军',
#  '分支',
#  '院校学习深',
#  '超极限',
#  '工作这',
#  '留校',
#  '调整好心',
#  '倒伏',
#  '盯着',
#  '外部力量',
#  '从某种意义上',
#  '由于这种',
#  '对新华社记者',
#  '通过比武',
#  '成果文件',
#  '个时间',
#  '渔业资源',
#  '受影响',
#  '时间上',
#  '联合部队',
#  '在本月',
#  '马上就',
#  '包括一架',
#  '守住底',
#  '采取',
#  '如履平',
#  '编码',
#  '鞠躬',
#  '防灾演',
#  '要履行',
#  '舍己救',
#  '小说',
#  '给官兵',
#  '合作部',
#  '母船上',
#  '隆重开幕',
#  '被淹',
#  '大会上发',
#  '军衔',
#  '各级',
#  '连队根据他',
#  '模式',
#  '也许不',
#  '忘我',
#  '中受益',
#  '试验型',
#  '待这些',
#  '遍及',
#  '在越南',
#  '这一发',
#  '出美国',
#  '得胜',
#  '设施齐全',
#  '表示感',
#  '系统而言',
#  '假象',
#  '美国社会',
#  '们准备',
#  '部队最',
#  '富强',
#  '铁路运输',
#  '员纷纷',
#  '不通过',
#  '数据进行',
#  '箴言',
#  '外训中',
#  '均匀',
#  '我们手',
#  '由于军',
#  '军区第',
#  '出人意料地',
#  '四引擎',
#  '军事文',
#  '会主席',
#  '防护',
#  '个战斗',
#  '年被军区',
#  '能检测',
#  '访问印度',
#  '人员上',
#  '请假',
#  '高水',
#  '没有任何军',
#  '较大等',
#  '商务',
#  '各参演',
#  '特色军事文',
#  '光滑',
#  '大洋之',
#  '之夜',
#  '上下铺',
#  '保障系统',
#  '暴力',
#  '怎么',
#  '们只能',
#  '提高俄',
#  '半个世纪以来',
#  '美国国会',
#  '装备俄',
#  '应该在',
#  '次冲',
#  '该委员会提出',
#  '大字',
#  '船护航',
#  '纪念',
#  '在本届',
#  '邀请参',
#  '全程监督',
#  '团一部',
#  '并迅速',
#  '严正',
#  '范畴之内',
#  '技术推',
#  '天气状',
#  '等活动',
#  '灵光',
#  '着自',
#  '名战士考',
#  '信息服务',
#  '空对地导弹',
#  '份文',
#  '政府军队',
#  '硬气',
#  '国已经',
#  '法纪教',
#  '坎贝尔',
#  '防空战',
#  '分子进行',
#  '就足够',
#  '正式接',
#  '名驾驶',
#  '交流日益',
#  '依山',
#  '得到这',
#  '处理',
#  '进入海',
#  '抓好工作落实',
#  '罗战军',
#  '问题同',
#  '手电筒',
#  '不确定因素',
#  '扎根基',
#  '机关全体官兵',
#  '中处于',
#  '传递出',
#  '战友',
#  '青年官兵',
#  '后勤装备',
#  '本年度',
#  '在能力',
#  '重要政治',
#  '车内',
#  '新变化',
#  '部门在',
#  '成一些',
#  '发生冲突',
#  '之音',
#  '个科目',
#  '训练法规',
#  '地域',
#  '思想',
#  '话语',
#  '国实现',
#  '通过不断',
#  '罚款',
#  '培训教',
#  '分辨',
#  '母船',
#  '雷区',
#  '献身国防',
#  '能力考核',
#  '他们虽',
#  '敢于担当',
#  '美国研制',
#  '战备值班',
#  '创新方法',
#  '炎炎',
#  '这段时间',
#  '多次出色完成',
#  '理论讲',
#  '工作生活',
#  '培训活动',
#  '本职',
#  '不可',
#  '叙利亚危',
#  '列装后',
#  '狂风',
#  '精雕细',
#  '每名官兵都',
#  '环境建设',
#  '伟大成就',
#  '分路突',
#  '查数据',
#  '不稳定',
#  '已经拥有',
#  '这些军',
#  '朝鲜在',
#  '海外部',
#  '三沙警备区',
#  '在返回',
#  '获得第一',
#  '出地球',
#  '大责任',
#  '同时注意',
#  '展开训',
#  '海况下',
#  '谓之',
#  '联合军事演习',
#  '地利用',
#  '司法局',
#  '一个老',
#  '各大单位',
#  '难题会',
#  '后逃逸',
#  '罪犯',
#  '特工',
#  '一次调研',
#  '兼总',
#  '立身',
#  '优抚',
#  '有战略',
#  '人瞩',
#  '由国防大学',
#  '风筝',
#  '疏堵结合',
#  '在雨中',
#  '个可以',
#  '有太多',
#  '手术',
#  '投下',
#  '从这一刻起',
#  '考核不',
#  '尔曾',
#  '山坳',
#  '全能第',
#  '大队大队长',
#  '及相关',
#  '理效',
#  '将越来越',
#  '保障时',
#  '重点项目',
#  ...]

# %%
with open("new_words.txt", "w", encoding="utf-8") as f:
    for new_word in new_words2:
        f.write(new_word + "\n")
